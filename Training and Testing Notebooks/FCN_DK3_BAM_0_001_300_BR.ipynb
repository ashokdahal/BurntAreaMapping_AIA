# %% [markdown]
# <a href="https://colab.research.google.com/github/ashokdahal/BurntAreaMapping_AIA/blob/main/FCN_DK3_BAM_0_001_300_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Burnt Area Mapping using FCNN and the Sentinel 2 Images using FCN-DK2</h1>
# Code Author: Ashok Dahal
#
# ***This code is developed for the assignment of the Advanced Image Analysis Course, and hence, has not been peer reviewd and verfied, use at your own risk***

# %% [markdown]
# # Load libraries and prepare connect to data folders

# %%
#connect to the goolge drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import the required Libraries
import os
import numpy as np
import gdal
import keras
import tensorflow as tf
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage import exposure
from google.colab import drive
import tensorflow as tf

from keras.models import Sequential
from keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Activation, BatchNormalization, Reshape
from keras import backend as K
from keras.optimizers import SGD, Adadelta

import tensorflow.python.keras.backend as K
sess = K.get_session()
from tensorflow.compat.v1.keras.backend import set_session
from keras.layers import LeakyReLU
import pickle
import matplotlib.pyplot as plt 
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Define File directories
Data_folder = "/content/drive/My Drive/AIA_colab/Forest_fire/Classified Tiles"
IMAGE_PATH = os.path.join(Data_folder, "ImageNBR")
LABEL_PATH = os.path.join(Data_folder, "Label")

# %% [markdown]
# #Load and Prepare the required dataset

# %%
#Create list of sentinel images 
image_list={}
for f in sorted(os.listdir(IMAGE_PATH)):
    fdir = os.path.join(IMAGE_PATH, f)
    _, ext = os.path.splitext(f)
    if ext.lower() == ".tif":
        imgtype = f[-9:-4]
        image_data=gdal.Open(fdir)
        bands = [image_data.GetRasterBand(image_data.RasterCount).ReadAsArray()]
        image_list[imgtype] = np.stack(bands, axis=2)

# %%
#Create list of Lables
label_list={}
for f in sorted(os.listdir(LABEL_PATH)):
    fdir = os.path.join(LABEL_PATH, f)
    _, ext = os.path.splitext(f)
    if ext.lower() == ".tif":
        imgtype = f[-9:-4]
        label_data=gdal.Open(fdir)
        bands = [label_data.GetRasterBand(label_data.RasterCount).ReadAsArray()]
        label_list[imgtype] = np.stack(bands, axis=2)

# %%
#visualize both images 
sample_image="00004"
sample_label="00004"

def visualize_data(data,data2):
    f, axarr = plt.subplots(1,2)

    im = axarr[0].imshow(data[:,:,0])
    axarr[0].set_title("Satellite image")

    a=axarr[1]
    values = np.unique(data2.ravel())
    im = axarr[1].imshow(data2[:,:,0])
    a.set_title("Labeled image")
    colors = [im.cmap(im.norm(value)) for value in values] 
    data2 = ["Not Burnt Area", "Burnt Area"]
    patches = [mpatches.Patch(color=colors[i], label=j) for i, j in zip(range(len(values)), data2)]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

visualize_data(image_list[sample_image],label_list[sample_label])

# %%
#convert data into smaller patches and keras usable formats

PATCHSIZE = 128
NBANDS = image_list["00001"].shape[-1]

def gridwise_sample(imgarray, patchsize):
    """Extract sample patches of size patchsize x patchsize from an image (imgarray) in a gridwise manner.
    """
    nrows, ncols, nbands = imgarray.shape
    patchsamples = np.zeros(shape=(0, patchsize, patchsize, nbands),
                            dtype=imgarray.dtype)
    for i in range(int(nrows/patchsize)):
        for j in range(int(ncols/patchsize)):
            tocat = imgarray[i*patchsize:(i+1)*patchsize,
                             j*patchsize:(j+1)*patchsize, :]
            tocat = np.expand_dims(tocat, axis=0)
            patchsamples = np.concatenate((patchsamples, tocat),
                                          axis=0)
    return patchsamples

Xtrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
Ytrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.uint8)
# sample each training tile systematically in a gridwise manner
train_areas = ["00000", "00002", "00003","00004","00005","00010","00012","00013"] #00001 and 00011 are used as test
for area in train_areas:
    X_toadd = gridwise_sample(image_list[area], PATCHSIZE)
    Y_toadd = gridwise_sample(label_list[area], PATCHSIZE)
    Xtrain = np.concatenate((Xtrain, X_toadd), axis=0)
    Ytrain = np.concatenate((Ytrain, Y_toadd), axis=0)
# encode all non-informal settlement classes as one class
Ytrain[Ytrain!=2] = 1
print("There are %i number of training patches" % (Xtrain.shape[0]))
# Out:
# There are 1800 number of training patches

# %%
nb_px=len(Ytrain[Ytrain==1])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==2]))
yb_px=len(Ytrain[Ytrain==2])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==2]))
print("there are %f percent pixels of burnt pixels and %f percent pixels of not burnt pixels" % (yb_px*100,nb_px*100) )
# Out:
# there are 33.545169 percent pixels of burnt pixels and 66.454831 percent pixels of not burnt pixels

# %%
#Visualize the Patches of Image
PATCH_NO = 490
visualize_data(Xtrain[PATCH_NO],Ytrain[PATCH_NO])

# %% [markdown]
# Convert Label data to categorical

# %%
def to_categorical_4d(y, nc):
    Y = np.zeros((y.shape[0],
                  y.shape[1],
                  y.shape[2],
                  nc),
                  dtype=np.int32)
    for h in range(y.shape[0]):
        for i in range(y.shape[1]):
            for j in range(y.shape[2]):
                if y[h, i, j, 0] != 0:
                    Y[h, i, j, y[h, i, j, 0]-1] = 1
                else:
                    continue
    return Y
# transform target arrays to one-hot encodings
Ytrain = to_categorical_4d(Ytrain, 2)

# %% [markdown]
# # Create a FCNN model and train it

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2
set_session(tf.compat.v1.Session(config=config))

NUMBER_BANDS = 1
NUMBER_CLASSES = 2
NUMBER_EPOCHS = 300 
nclasses=2
def build_FCN(optimizer, nrows, ncols, nbands,nclasses):
    model = keras.models.Sequential()
    model.add(ZeroPadding2D((2, 2), input_shape=(nrows, ncols, nbands)))
    model.add(Convolution2D(
              filters=32,
              kernel_size=(5, 5),
              dilation_rate=(1, 1)))
    model.add(BatchNormalization(axis=3))
    model.add(LeakyReLU(0.1))
    model.add(ZeroPadding2D((2, 2)))
    model.add(MaxPooling2D(
              pool_size=(5, 5),
              strides=(1, 1)
    ))
    model.add(ZeroPadding2D((4, 4)))
    model.add(Convolution2D(
              filters=32,
              kernel_size=(5, 5),
              dilation_rate=(2, 2)
    ))
    model.add(BatchNormalization(axis=3))
    model.add(LeakyReLU(0.1))
    model.add(ZeroPadding2D((4, 4)))
    model.add(MaxPooling2D(
            pool_size=(9, 9),
            strides=(1, 1)
    ))
    model.add(ZeroPadding2D((6, 6)))
    model.add(Convolution2D(
              filters=32,
              kernel_size=(5, 5),
              dilation_rate=(3, 3)
    ))
    model.add(BatchNormalization(axis=3))
    model.add(LeakyReLU(0.1))
    model.add(ZeroPadding2D((6, 6)))
    model.add(MaxPooling2D(
            pool_size=(13, 13),
            strides=(1, 1)
    ))
    model.add(Convolution2D(
              filters=nclasses,
              kernel_size=(1, 1)
    ))
    model.add(keras.layers.Activation(
              activation="softmax"
    ))
    model.compile(loss="categorical_crossentropy", metrics=['accuracy'], optimizer=optimizer)
    return model

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

opt = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
fcn = build_FCN(opt, PATCHSIZE, PATCHSIZE, NUMBER_BANDS,NUMBER_CLASSES)

fcn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m]) #'adam'

# %%
fcn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_6 (ZeroPaddin (None, 132, 132, 7)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 32)      5632
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 32)      0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 132, 132, 32)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 136, 136, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 32)      25632
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128, 128, 32)      0
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 136, 136, 32)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 140, 140, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 32)      25632
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128, 128, 32)      0
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 140, 140, 32)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 2)       66
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 2)       0
# =================================================================
# Total params: 57,346
# Trainable params: 57,154
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# Train the Model

# %%
def train(model, data, labels):
    hist = model.fit(x=data,
                     y=labels,
                     epochs=NUMBER_EPOCHS,
                     validation_split=0.20,
                     verbose=2
                    )
    return hist

history = train(fcn, Xtrain, Ytrain)
# Out:
# Epoch 1/300
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0069s vs `on_train_batch_end` time: 0.1666s). Check your callbacks.
# 45/45 - 9s - loss: 0.2151 - acc: 0.9214 - f1_m: 0.9214 - precision_m: 0.9214 - recall_m: 0.9214 - val_loss: 0.3074 - val_acc: 0.8360 - val_f1_m: 0.8463 - val_precision_m: 0.8463 - val_recall_m: 0.8463
# Epoch 2/300
# 45/45 - 9s - loss: 0.1624 - acc: 0.9483 - f1_m: 0.9483 - precision_m: 0.9483 - recall_m: 0.9483 - val_loss: 0.4670 - val_acc: 0.8261 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 3/300
# 45/45 - 9s - loss: 0.1625 - acc: 0.9462 - f1_m: 0.9462 - precision_m: 0.9462 - recall_m: 0.9462 - val_loss: 0.5279 - val_acc: 0.8261 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 4/300
# 45/45 - 9s - loss: 0.1601 - acc: 0.9478 - f1_m: 0.9478 - precision_m: 0.9478 - recall_m: 0.9478 - val_loss: 0.7358 - val_acc: 0.8261 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 5/300
# 45/45 - 9s - loss: 0.1518 - acc: 0.9518 - f1_m: 0.9518 - precision_m: 0.9518 - recall_m: 0.9518 - val_loss: 0.6740 - val_acc: 0.8261 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 6/300
# 45/45 - 8s - loss: 0.1443 - acc: 0.9532 - f1_m: 0.9532 - precision_m: 0.9532 - recall_m: 0.9532 - val_loss: 0.9708 - val_acc: 0.8261 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 7/300
# 45/45 - 8s - loss: 0.1436 - acc: 0.9538 - f1_m: 0.9538 - precision_m: 0.9538 - recall_m: 0.9538 - val_loss: 0.5526 - val_acc: 0.8262 - val_f1_m: 0.8370 - val_precision_m: 0.8370 - val_recall_m: 0.8370
# Epoch 8/300
# 45/45 - 8s - loss: 0.1319 - acc: 0.9585 - f1_m: 0.9585 - precision_m: 0.9585 - recall_m: 0.9585 - val_loss: 0.5980 - val_acc: 0.8262 - val_f1_m: 0.8371 - val_precision_m: 0.8371 - val_recall_m: 0.8371
# Epoch 9/300
# 45/45 - 8s - loss: 0.1396 - acc: 0.9537 - f1_m: 0.9537 - precision_m: 0.9537 - recall_m: 0.9537 - val_loss: 0.3167 - val_acc: 0.8611 - val_f1_m: 0.8698 - val_precision_m: 0.8698 - val_recall_m: 0.8698
# Epoch 10/300
# 45/45 - 8s - loss: 0.1320 - acc: 0.9583 - f1_m: 0.9583 - precision_m: 0.9583 - recall_m: 0.9583 - val_loss: 0.1672 - val_acc: 0.9457 - val_f1_m: 0.9491 - val_precision_m: 0.9491 - val_recall_m: 0.9491
# Epoch 11/300
# 45/45 - 8s - loss: 0.1364 - acc: 0.9551 - f1_m: 0.9551 - precision_m: 0.9551 - recall_m: 0.9551 - val_loss: 0.1454 - val_acc: 0.9560 - val_f1_m: 0.9587 - val_precision_m: 0.9587 - val_recall_m: 0.9587
# Epoch 12/300
# 45/45 - 9s - loss: 0.1445 - acc: 0.9519 - f1_m: 0.9519 - precision_m: 0.9519 - recall_m: 0.9519 - val_loss: 0.4213 - val_acc: 0.9492 - val_f1_m: 0.9523 - val_precision_m: 0.9523 - val_recall_m: 0.9523
# Epoch 13/300
# 45/45 - 9s - loss: 0.1244 - acc: 0.9595 - f1_m: 0.9595 - precision_m: 0.9595 - recall_m: 0.9595 - val_loss: 0.2779 - val_acc: 0.9580 - val_f1_m: 0.9607 - val_precision_m: 0.9607 - val_recall_m: 0.9607
# Epoch 14/300
# 45/45 - 9s - loss: 0.1216 - acc: 0.9615 - f1_m: 0.9615 - precision_m: 0.9615 - recall_m: 0.9615 - val_loss: 0.1895 - val_acc: 0.9593 - val_f1_m: 0.9618 - val_precision_m: 0.9618 - val_recall_m: 0.9618
# Epoch 15/300
# 45/45 - 9s - loss: 0.1185 - acc: 0.9619 - f1_m: 0.9619 - precision_m: 0.9619 - recall_m: 0.9619 - val_loss: 0.1992 - val_acc: 0.9589 - val_f1_m: 0.9614 - val_precision_m: 0.9614 - val_recall_m: 0.9614
# Epoch 16/300
# 45/45 - 9s - loss: 0.1244 - acc: 0.9602 - f1_m: 0.9602 - precision_m: 0.9602 - recall_m: 0.9602 - val_loss: 0.3678 - val_acc: 0.9528 - val_f1_m: 0.9558 - val_precision_m: 0.9558 - val_recall_m: 0.9558
# Epoch 17/300
# 45/45 - 8s - loss: 0.1277 - acc: 0.9575 - f1_m: 0.9575 - precision_m: 0.9575 - recall_m: 0.9575 - val_loss: 0.4629 - val_acc: 0.9268 - val_f1_m: 0.9313 - val_precision_m: 0.9313 - val_recall_m: 0.9313
# Epoch 18/300
# 45/45 - 8s - loss: 0.1190 - acc: 0.9621 - f1_m: 0.9621 - precision_m: 0.9621 - recall_m: 0.9621 - val_loss: 0.2833 - val_acc: 0.9511 - val_f1_m: 0.9542 - val_precision_m: 0.9542 - val_recall_m: 0.9542
# Epoch 19/300
# 45/45 - 8s - loss: 0.1363 - acc: 0.9532 - f1_m: 0.9532 - precision_m: 0.9532 - recall_m: 0.9532 - val_loss: 0.4172 - val_acc: 0.9246 - val_f1_m: 0.9292 - val_precision_m: 0.9292 - val_recall_m: 0.9292
# Epoch 20/300
# 45/45 - 8s - loss: 0.1325 - acc: 0.9559 - f1_m: 0.9559 - precision_m: 0.9559 - recall_m: 0.9559 - val_loss: 0.3865 - val_acc: 0.9315 - val_f1_m: 0.9358 - val_precision_m: 0.9358 - val_recall_m: 0.9358
# Epoch 21/300
# 45/45 - 8s - loss: 0.1223 - acc: 0.9605 - f1_m: 0.9605 - precision_m: 0.9605 - recall_m: 0.9605 - val_loss: 0.3342 - val_acc: 0.9518 - val_f1_m: 0.9549 - val_precision_m: 0.9549 - val_recall_m: 0.9549
# Epoch 22/300
# 45/45 - 8s - loss: 0.1220 - acc: 0.9607 - f1_m: 0.9607 - precision_m: 0.9607 - recall_m: 0.9607 - val_loss: 0.2692 - val_acc: 0.9575 - val_f1_m: 0.9601 - val_precision_m: 0.9601 - val_recall_m: 0.9601
# Epoch 23/300
# 45/45 - 8s - loss: 0.1112 - acc: 0.9644 - f1_m: 0.9644 - precision_m: 0.9644 - recall_m: 0.9644 - val_loss: 0.3973 - val_acc: 0.9376 - val_f1_m: 0.9415 - val_precision_m: 0.9415 - val_recall_m: 0.9415
# Epoch 24/300
# 45/45 - 8s - loss: 0.1077 - acc: 0.9641 - f1_m: 0.9641 - precision_m: 0.9641 - recall_m: 0.9641 - val_loss: 0.3472 - val_acc: 0.9492 - val_f1_m: 0.9524 - val_precision_m: 0.9524 - val_recall_m: 0.9524
# Epoch 25/300
# 45/45 - 8s - loss: 0.1172 - acc: 0.9607 - f1_m: 0.9607 - precision_m: 0.9607 - recall_m: 0.9607 - val_loss: 0.3146 - val_acc: 0.9392 - val_f1_m: 0.9430 - val_precision_m: 0.9430 - val_recall_m: 0.9430
# Epoch 26/300
# 45/45 - 9s - loss: 0.1158 - acc: 0.9621 - f1_m: 0.9621 - precision_m: 0.9621 - recall_m: 0.9621 - val_loss: 0.1763 - val_acc: 0.9562 - val_f1_m: 0.9590 - val_precision_m: 0.9590 - val_recall_m: 0.9590
# Epoch 27/300
# 45/45 - 8s - loss: 0.1175 - acc: 0.9609 - f1_m: 0.9609 - precision_m: 0.9609 - recall_m: 0.9609 - val_loss: 0.2603 - val_acc: 0.9560 - val_f1_m: 0.9587 - val_precision_m: 0.9587 - val_recall_m: 0.9587
# Epoch 28/300
# 45/45 - 8s - loss: 0.1063 - acc: 0.9642 - f1_m: 0.9642 - precision_m: 0.9642 - recall_m: 0.9642 - val_loss: 0.3320 - val_acc: 0.9499 - val_f1_m: 0.9530 - val_precision_m: 0.9530 - val_recall_m: 0.9530
# Epoch 29/300
# 45/45 - 9s - loss: 0.1163 - acc: 0.9611 - f1_m: 0.9611 - precision_m: 0.9611 - recall_m: 0.9611 - val_loss: 0.2283 - val_acc: 0.9548 - val_f1_m: 0.9576 - val_precision_m: 0.9576 - val_recall_m: 0.9576
# Epoch 30/300
# 45/45 - 9s - loss: 0.1075 - acc: 0.9642 - f1_m: 0.9642 - precision_m: 0.9642 - recall_m: 0.9642 - val_loss: 0.2921 - val_acc: 0.9424 - val_f1_m: 0.9460 - val_precision_m: 0.9460 - val_recall_m: 0.9460
# Epoch 31/300
# 45/45 - 8s - loss: 0.1093 - acc: 0.9639 - f1_m: 0.9639 - precision_m: 0.9639 - recall_m: 0.9639 - val_loss: 0.1759 - val_acc: 0.9572 - val_f1_m: 0.9598 - val_precision_m: 0.9598 - val_recall_m: 0.9598
# Epoch 32/300
# 45/45 - 9s - loss: 0.1058 - acc: 0.9656 - f1_m: 0.9656 - precision_m: 0.9656 - recall_m: 0.9656 - val_loss: 0.2479 - val_acc: 0.9561 - val_f1_m: 0.9588 - val_precision_m: 0.9588 - val_recall_m: 0.9588
# Epoch 33/300
# 45/45 - 8s - loss: 0.1038 - acc: 0.9657 - f1_m: 0.9657 - precision_m: 0.9657 - recall_m: 0.9657 - val_loss: 0.2447 - val_acc: 0.9578 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 34/300
# 45/45 - 9s - loss: 0.1081 - acc: 0.9634 - f1_m: 0.9634 - precision_m: 0.9634 - recall_m: 0.9634 - val_loss: 0.2541 - val_acc: 0.9564 - val_f1_m: 0.9592 - val_precision_m: 0.9592 - val_recall_m: 0.9592
# Epoch 35/300
# 45/45 - 8s - loss: 0.1026 - acc: 0.9656 - f1_m: 0.9656 - precision_m: 0.9656 - recall_m: 0.9656 - val_loss: 0.1905 - val_acc: 0.9527 - val_f1_m: 0.9556 - val_precision_m: 0.9556 - val_recall_m: 0.9556
# Epoch 36/300
# 45/45 - 8s - loss: 0.1064 - acc: 0.9647 - f1_m: 0.9647 - precision_m: 0.9647 - recall_m: 0.9647 - val_loss: 0.1892 - val_acc: 0.9587 - val_f1_m: 0.9613 - val_precision_m: 0.9613 - val_recall_m: 0.9613
# Epoch 37/300
# 45/45 - 9s - loss: 0.1100 - acc: 0.9632 - f1_m: 0.9632 - precision_m: 0.9632 - recall_m: 0.9632 - val_loss: 0.4075 - val_acc: 0.9384 - val_f1_m: 0.9422 - val_precision_m: 0.9422 - val_recall_m: 0.9422
# Epoch 38/300
# 45/45 - 8s - loss: 0.1092 - acc: 0.9643 - f1_m: 0.9643 - precision_m: 0.9643 - recall_m: 0.9643 - val_loss: 0.3535 - val_acc: 0.9424 - val_f1_m: 0.9460 - val_precision_m: 0.9460 - val_recall_m: 0.9460
# Epoch 39/300
# 45/45 - 9s - loss: 0.1106 - acc: 0.9624 - f1_m: 0.9624 - precision_m: 0.9624 - recall_m: 0.9624 - val_loss: 0.5642 - val_acc: 0.9075 - val_f1_m: 0.9133 - val_precision_m: 0.9133 - val_recall_m: 0.9133
# Epoch 40/300
# 45/45 - 9s - loss: 0.1199 - acc: 0.9600 - f1_m: 0.9600 - precision_m: 0.9600 - recall_m: 0.9600 - val_loss: 0.5021 - val_acc: 0.8675 - val_f1_m: 0.8742 - val_precision_m: 0.8742 - val_recall_m: 0.8742
# Epoch 41/300
# 45/45 - 9s - loss: 0.1072 - acc: 0.9645 - f1_m: 0.9645 - precision_m: 0.9645 - recall_m: 0.9645 - val_loss: 0.2559 - val_acc: 0.9532 - val_f1_m: 0.9561 - val_precision_m: 0.9561 - val_recall_m: 0.9561
# Epoch 42/300
# 45/45 - 9s - loss: 0.1072 - acc: 0.9643 - f1_m: 0.9643 - precision_m: 0.9643 - recall_m: 0.9643 - val_loss: 0.1957 - val_acc: 0.9577 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 43/300
# 45/45 - 8s - loss: 0.1005 - acc: 0.9667 - f1_m: 0.9667 - precision_m: 0.9667 - recall_m: 0.9667 - val_loss: 0.2291 - val_acc: 0.9585 - val_f1_m: 0.9611 - val_precision_m: 0.9611 - val_recall_m: 0.9611
# Epoch 44/300
# 45/45 - 9s - loss: 0.1082 - acc: 0.9634 - f1_m: 0.9634 - precision_m: 0.9634 - recall_m: 0.9634 - val_loss: 0.2852 - val_acc: 0.9492 - val_f1_m: 0.9524 - val_precision_m: 0.9524 - val_recall_m: 0.9524
# Epoch 45/300
# 45/45 - 8s - loss: 0.0929 - acc: 0.9689 - f1_m: 0.9689 - precision_m: 0.9689 - recall_m: 0.9689 - val_loss: 0.2073 - val_acc: 0.9586 - val_f1_m: 0.9612 - val_precision_m: 0.9612 - val_recall_m: 0.9612
# Epoch 46/300
# 45/45 - 9s - loss: 0.0981 - acc: 0.9674 - f1_m: 0.9674 - precision_m: 0.9674 - recall_m: 0.9674 - val_loss: 0.2138 - val_acc: 0.9581 - val_f1_m: 0.9607 - val_precision_m: 0.9607 - val_recall_m: 0.9607
# Epoch 47/300
# 45/45 - 9s - loss: 0.1112 - acc: 0.9622 - f1_m: 0.9622 - precision_m: 0.9622 - recall_m: 0.9622 - val_loss: 0.1690 - val_acc: 0.9523 - val_f1_m: 0.9553 - val_precision_m: 0.9553 - val_recall_m: 0.9553
# Epoch 48/300
# 45/45 - 9s - loss: 0.0984 - acc: 0.9667 - f1_m: 0.9667 - precision_m: 0.9667 - recall_m: 0.9667 - val_loss: 0.3465 - val_acc: 0.9430 - val_f1_m: 0.9466 - val_precision_m: 0.9466 - val_recall_m: 0.9466
# Epoch 49/300
# 45/45 - 9s - loss: 0.1065 - acc: 0.9644 - f1_m: 0.9644 - precision_m: 0.9644 - recall_m: 0.9644 - val_loss: 0.3174 - val_acc: 0.9495 - val_f1_m: 0.9527 - val_precision_m: 0.9527 - val_recall_m: 0.9527
# Epoch 50/300
# 45/45 - 9s - loss: 0.1108 - acc: 0.9623 - f1_m: 0.9623 - precision_m: 0.9623 - recall_m: 0.9623 - val_loss: 0.5190 - val_acc: 0.9058 - val_f1_m: 0.9117 - val_precision_m: 0.9117 - val_recall_m: 0.9117
# Epoch 51/300
# 45/45 - 9s - loss: 0.0994 - acc: 0.9671 - f1_m: 0.9671 - precision_m: 0.9671 - recall_m: 0.9671 - val_loss: 0.1885 - val_acc: 0.9595 - val_f1_m: 0.9620 - val_precision_m: 0.9620 - val_recall_m: 0.9620
# Epoch 52/300
# 45/45 - 9s - loss: 0.1113 - acc: 0.9611 - f1_m: 0.9611 - precision_m: 0.9611 - recall_m: 0.9611 - val_loss: 0.4294 - val_acc: 0.9180 - val_f1_m: 0.9231 - val_precision_m: 0.9231 - val_recall_m: 0.9231
# Epoch 53/300
# 45/45 - 9s - loss: 0.0997 - acc: 0.9659 - f1_m: 0.9659 - precision_m: 0.9659 - recall_m: 0.9659 - val_loss: 0.3053 - val_acc: 0.9461 - val_f1_m: 0.9495 - val_precision_m: 0.9495 - val_recall_m: 0.9495
# Epoch 54/300
# 45/45 - 9s - loss: 0.1087 - acc: 0.9633 - f1_m: 0.9633 - precision_m: 0.9633 - recall_m: 0.9633 - val_loss: 0.4951 - val_acc: 0.9090 - val_f1_m: 0.9147 - val_precision_m: 0.9147 - val_recall_m: 0.9147
# Epoch 55/300
# 45/45 - 9s - loss: 0.0992 - acc: 0.9654 - f1_m: 0.9654 - precision_m: 0.9654 - recall_m: 0.9654 - val_loss: 0.2340 - val_acc: 0.9558 - val_f1_m: 0.9585 - val_precision_m: 0.9585 - val_recall_m: 0.9585
# Epoch 56/300
# 45/45 - 9s - loss: 0.0908 - acc: 0.9684 - f1_m: 0.9684 - precision_m: 0.9684 - recall_m: 0.9684 - val_loss: 0.3639 - val_acc: 0.9491 - val_f1_m: 0.9523 - val_precision_m: 0.9523 - val_recall_m: 0.9523
# Epoch 57/300
# 45/45 - 9s - loss: 0.1061 - acc: 0.9643 - f1_m: 0.9643 - precision_m: 0.9643 - recall_m: 0.9643 - val_loss: 0.2001 - val_acc: 0.9591 - val_f1_m: 0.9616 - val_precision_m: 0.9616 - val_recall_m: 0.9616
# Epoch 58/300
# 45/45 - 8s - loss: 0.0922 - acc: 0.9684 - f1_m: 0.9684 - precision_m: 0.9684 - recall_m: 0.9684 - val_loss: 0.3208 - val_acc: 0.9522 - val_f1_m: 0.9551 - val_precision_m: 0.9551 - val_recall_m: 0.9551
# Epoch 59/300
# 45/45 - 8s - loss: 0.1019 - acc: 0.9648 - f1_m: 0.9648 - precision_m: 0.9648 - recall_m: 0.9648 - val_loss: 0.2713 - val_acc: 0.9530 - val_f1_m: 0.9559 - val_precision_m: 0.9559 - val_recall_m: 0.9559
# Epoch 60/300
# 45/45 - 8s - loss: 0.0947 - acc: 0.9673 - f1_m: 0.9673 - precision_m: 0.9673 - recall_m: 0.9673 - val_loss: 0.2783 - val_acc: 0.9554 - val_f1_m: 0.9581 - val_precision_m: 0.9581 - val_recall_m: 0.9581
# Epoch 61/300
# 45/45 - 9s - loss: 0.1001 - acc: 0.9661 - f1_m: 0.9661 - precision_m: 0.9661 - recall_m: 0.9661 - val_loss: 0.1593 - val_acc: 0.9545 - val_f1_m: 0.9574 - val_precision_m: 0.9574 - val_recall_m: 0.9574
# Epoch 62/300
# 45/45 - 9s - loss: 0.0954 - acc: 0.9678 - f1_m: 0.9678 - precision_m: 0.9678 - recall_m: 0.9678 - val_loss: 0.3226 - val_acc: 0.9517 - val_f1_m: 0.9547 - val_precision_m: 0.9547 - val_recall_m: 0.9547
# Epoch 63/300
# 45/45 - 8s - loss: 0.0930 - acc: 0.9679 - f1_m: 0.9679 - precision_m: 0.9679 - recall_m: 0.9679 - val_loss: 0.2507 - val_acc: 0.9556 - val_f1_m: 0.9584 - val_precision_m: 0.9584 - val_recall_m: 0.9584
# Epoch 64/300
# 45/45 - 9s - loss: 0.0965 - acc: 0.9670 - f1_m: 0.9670 - precision_m: 0.9670 - recall_m: 0.9670 - val_loss: 0.4197 - val_acc: 0.9412 - val_f1_m: 0.9448 - val_precision_m: 0.9448 - val_recall_m: 0.9448
# Epoch 65/300
# 45/45 - 9s - loss: 0.0973 - acc: 0.9669 - f1_m: 0.9669 - precision_m: 0.9669 - recall_m: 0.9669 - val_loss: 0.1827 - val_acc: 0.9561 - val_f1_m: 0.9588 - val_precision_m: 0.9588 - val_recall_m: 0.9588
# Epoch 66/300
# 45/45 - 9s - loss: 0.0909 - acc: 0.9688 - f1_m: 0.9688 - precision_m: 0.9688 - recall_m: 0.9688 - val_loss: 0.1882 - val_acc: 0.9568 - val_f1_m: 0.9595 - val_precision_m: 0.9595 - val_recall_m: 0.9595
# Epoch 67/300
# 45/45 - 9s - loss: 0.0942 - acc: 0.9679 - f1_m: 0.9679 - precision_m: 0.9679 - recall_m: 0.9679 - val_loss: 0.1793 - val_acc: 0.9592 - val_f1_m: 0.9617 - val_precision_m: 0.9617 - val_recall_m: 0.9617
# Epoch 68/300
# 45/45 - 9s - loss: 0.0875 - acc: 0.9697 - f1_m: 0.9697 - precision_m: 0.9697 - recall_m: 0.9697 - val_loss: 0.3207 - val_acc: 0.9400 - val_f1_m: 0.9438 - val_precision_m: 0.9438 - val_recall_m: 0.9438
# Epoch 69/300
# 45/45 - 9s - loss: 0.0883 - acc: 0.9693 - f1_m: 0.9693 - precision_m: 0.9693 - recall_m: 0.9693 - val_loss: 0.2261 - val_acc: 0.9575 - val_f1_m: 0.9602 - val_precision_m: 0.9602 - val_recall_m: 0.9602
# Epoch 70/300
# 45/45 - 9s - loss: 0.0929 - acc: 0.9675 - f1_m: 0.9675 - precision_m: 0.9675 - recall_m: 0.9675 - val_loss: 0.2049 - val_acc: 0.9579 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 71/300
# 45/45 - 9s - loss: 0.0877 - acc: 0.9697 - f1_m: 0.9697 - precision_m: 0.9697 - recall_m: 0.9697 - val_loss: 0.2157 - val_acc: 0.9540 - val_f1_m: 0.9566 - val_precision_m: 0.9566 - val_recall_m: 0.9566
# Epoch 72/300
# 45/45 - 8s - loss: 0.0955 - acc: 0.9665 - f1_m: 0.9665 - precision_m: 0.9665 - recall_m: 0.9665 - val_loss: 0.3543 - val_acc: 0.9315 - val_f1_m: 0.9354 - val_precision_m: 0.9354 - val_recall_m: 0.9354
# Epoch 73/300
# 45/45 - 9s - loss: 0.0937 - acc: 0.9674 - f1_m: 0.9674 - precision_m: 0.9674 - recall_m: 0.9674 - val_loss: 0.2244 - val_acc: 0.9564 - val_f1_m: 0.9591 - val_precision_m: 0.9591 - val_recall_m: 0.9591
# Epoch 74/300
# 45/45 - 9s - loss: 0.0919 - acc: 0.9688 - f1_m: 0.9688 - precision_m: 0.9688 - recall_m: 0.9688 - val_loss: 0.2282 - val_acc: 0.9528 - val_f1_m: 0.9557 - val_precision_m: 0.9557 - val_recall_m: 0.9557
# Epoch 75/300
# 45/45 - 9s - loss: 0.0896 - acc: 0.9689 - f1_m: 0.9689 - precision_m: 0.9689 - recall_m: 0.9689 - val_loss: 0.2490 - val_acc: 0.9546 - val_f1_m: 0.9575 - val_precision_m: 0.9575 - val_recall_m: 0.9575
# Epoch 76/300
# 45/45 - 8s - loss: 0.0851 - acc: 0.9704 - f1_m: 0.9704 - precision_m: 0.9704 - recall_m: 0.9704 - val_loss: 0.3791 - val_acc: 0.9398 - val_f1_m: 0.9434 - val_precision_m: 0.9434 - val_recall_m: 0.9434
# Epoch 77/300
# 45/45 - 9s - loss: 0.0957 - acc: 0.9670 - f1_m: 0.9670 - precision_m: 0.9670 - recall_m: 0.9670 - val_loss: 0.3430 - val_acc: 0.9399 - val_f1_m: 0.9434 - val_precision_m: 0.9434 - val_recall_m: 0.9434
# Epoch 78/300
# 45/45 - 8s - loss: 0.0894 - acc: 0.9690 - f1_m: 0.9690 - precision_m: 0.9690 - recall_m: 0.9690 - val_loss: 0.3582 - val_acc: 0.9448 - val_f1_m: 0.9482 - val_precision_m: 0.9482 - val_recall_m: 0.9482
# Epoch 79/300
# 45/45 - 9s - loss: 0.0905 - acc: 0.9694 - f1_m: 0.9694 - precision_m: 0.9694 - recall_m: 0.9694 - val_loss: 0.3656 - val_acc: 0.9278 - val_f1_m: 0.9322 - val_precision_m: 0.9322 - val_recall_m: 0.9322
# Epoch 80/300
# 45/45 - 9s - loss: 0.0871 - acc: 0.9696 - f1_m: 0.9696 - precision_m: 0.9696 - recall_m: 0.9696 - val_loss: 0.1758 - val_acc: 0.9538 - val_f1_m: 0.9566 - val_precision_m: 0.9566 - val_recall_m: 0.9566
# Epoch 81/300
# 45/45 - 9s - loss: 0.0909 - acc: 0.9697 - f1_m: 0.9697 - precision_m: 0.9697 - recall_m: 0.9697 - val_loss: 0.2246 - val_acc: 0.9577 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 82/300
# 45/45 - 9s - loss: 0.0922 - acc: 0.9684 - f1_m: 0.9684 - precision_m: 0.9684 - recall_m: 0.9684 - val_loss: 0.1926 - val_acc: 0.9590 - val_f1_m: 0.9616 - val_precision_m: 0.9616 - val_recall_m: 0.9616
# Epoch 83/300
# 45/45 - 9s - loss: 0.0908 - acc: 0.9678 - f1_m: 0.9678 - precision_m: 0.9678 - recall_m: 0.9678 - val_loss: 0.3171 - val_acc: 0.9457 - val_f1_m: 0.9490 - val_precision_m: 0.9490 - val_recall_m: 0.9490
# Epoch 84/300
# 45/45 - 9s - loss: 0.0883 - acc: 0.9702 - f1_m: 0.9702 - precision_m: 0.9702 - recall_m: 0.9702 - val_loss: 0.2043 - val_acc: 0.9593 - val_f1_m: 0.9618 - val_precision_m: 0.9618 - val_recall_m: 0.9618
# Epoch 85/300
# 45/45 - 9s - loss: 0.0950 - acc: 0.9679 - f1_m: 0.9679 - precision_m: 0.9679 - recall_m: 0.9679 - val_loss: 0.6537 - val_acc: 0.8156 - val_f1_m: 0.8212 - val_precision_m: 0.8212 - val_recall_m: 0.8212
# Epoch 86/300
# 45/45 - 9s - loss: 0.0929 - acc: 0.9672 - f1_m: 0.9672 - precision_m: 0.9672 - recall_m: 0.9672 - val_loss: 0.1651 - val_acc: 0.9538 - val_f1_m: 0.9567 - val_precision_m: 0.9567 - val_recall_m: 0.9567
# Epoch 87/300
# 45/45 - 9s - loss: 0.0842 - acc: 0.9707 - f1_m: 0.9707 - precision_m: 0.9707 - recall_m: 0.9707 - val_loss: 0.2084 - val_acc: 0.9561 - val_f1_m: 0.9588 - val_precision_m: 0.9588 - val_recall_m: 0.9588
# Epoch 88/300
# 45/45 - 9s - loss: 0.0835 - acc: 0.9708 - f1_m: 0.9708 - precision_m: 0.9708 - recall_m: 0.9708 - val_loss: 0.1790 - val_acc: 0.9573 - val_f1_m: 0.9600 - val_precision_m: 0.9600 - val_recall_m: 0.9600
# Epoch 89/300
# 45/45 - 9s - loss: 0.0862 - acc: 0.9704 - f1_m: 0.9704 - precision_m: 0.9704 - recall_m: 0.9704 - val_loss: 0.3334 - val_acc: 0.9521 - val_f1_m: 0.9551 - val_precision_m: 0.9551 - val_recall_m: 0.9551
# Epoch 90/300
# 45/45 - 9s - loss: 0.0858 - acc: 0.9698 - f1_m: 0.9698 - precision_m: 0.9698 - recall_m: 0.9698 - val_loss: 0.1882 - val_acc: 0.9440 - val_f1_m: 0.9475 - val_precision_m: 0.9475 - val_recall_m: 0.9475
# Epoch 91/300
# 45/45 - 9s - loss: 0.1004 - acc: 0.9663 - f1_m: 0.9663 - precision_m: 0.9663 - recall_m: 0.9663 - val_loss: 0.2797 - val_acc: 0.9490 - val_f1_m: 0.9522 - val_precision_m: 0.9522 - val_recall_m: 0.9522
# Epoch 92/300
# 45/45 - 9s - loss: 0.0876 - acc: 0.9695 - f1_m: 0.9695 - precision_m: 0.9695 - recall_m: 0.9695 - val_loss: 0.2662 - val_acc: 0.9489 - val_f1_m: 0.9521 - val_precision_m: 0.9521 - val_recall_m: 0.9521
# Epoch 93/300
# 45/45 - 9s - loss: 0.0820 - acc: 0.9714 - f1_m: 0.9714 - precision_m: 0.9714 - recall_m: 0.9714 - val_loss: 0.2128 - val_acc: 0.9582 - val_f1_m: 0.9608 - val_precision_m: 0.9608 - val_recall_m: 0.9608
# Epoch 94/300
# 45/45 - 9s - loss: 0.0869 - acc: 0.9705 - f1_m: 0.9705 - precision_m: 0.9705 - recall_m: 0.9705 - val_loss: 0.2949 - val_acc: 0.9539 - val_f1_m: 0.9568 - val_precision_m: 0.9568 - val_recall_m: 0.9568
# Epoch 95/300
# 45/45 - 9s - loss: 0.0828 - acc: 0.9713 - f1_m: 0.9713 - precision_m: 0.9713 - recall_m: 0.9713 - val_loss: 0.2301 - val_acc: 0.9571 - val_f1_m: 0.9598 - val_precision_m: 0.9598 - val_recall_m: 0.9598
# Epoch 96/300
# 45/45 - 9s - loss: 0.0854 - acc: 0.9704 - f1_m: 0.9704 - precision_m: 0.9704 - recall_m: 0.9704 - val_loss: 0.1712 - val_acc: 0.9571 - val_f1_m: 0.9598 - val_precision_m: 0.9598 - val_recall_m: 0.9598
# Epoch 97/300
# 45/45 - 9s - loss: 0.0830 - acc: 0.9711 - f1_m: 0.9711 - precision_m: 0.9711 - recall_m: 0.9711 - val_loss: 0.3490 - val_acc: 0.9271 - val_f1_m: 0.9312 - val_precision_m: 0.9312 - val_recall_m: 0.9312
# Epoch 98/300
# 45/45 - 9s - loss: 0.0799 - acc: 0.9716 - f1_m: 0.9716 - precision_m: 0.9716 - recall_m: 0.9716 - val_loss: 0.2992 - val_acc: 0.9468 - val_f1_m: 0.9501 - val_precision_m: 0.9501 - val_recall_m: 0.9501
# Epoch 99/300
# 45/45 - 9s - loss: 0.0923 - acc: 0.9670 - f1_m: 0.9670 - precision_m: 0.9670 - recall_m: 0.9670 - val_loss: 0.3519 - val_acc: 0.9172 - val_f1_m: 0.9223 - val_precision_m: 0.9223 - val_recall_m: 0.9223
# Epoch 100/300
# 45/45 - 9s - loss: 0.0823 - acc: 0.9716 - f1_m: 0.9716 - precision_m: 0.9716 - recall_m: 0.9716 - val_loss: 0.2195 - val_acc: 0.9581 - val_f1_m: 0.9606 - val_precision_m: 0.9606 - val_recall_m: 0.9606
# Epoch 101/300
# 45/45 - 9s - loss: 0.0777 - acc: 0.9728 - f1_m: 0.9728 - precision_m: 0.9728 - recall_m: 0.9728 - val_loss: 0.2179 - val_acc: 0.9561 - val_f1_m: 0.9589 - val_precision_m: 0.9589 - val_recall_m: 0.9589
# Epoch 102/300
# 45/45 - 8s - loss: 0.0833 - acc: 0.9708 - f1_m: 0.9708 - precision_m: 0.9708 - recall_m: 0.9708 - val_loss: 0.1979 - val_acc: 0.9585 - val_f1_m: 0.9611 - val_precision_m: 0.9611 - val_recall_m: 0.9611
# Epoch 103/300
# 45/45 - 9s - loss: 0.0734 - acc: 0.9743 - f1_m: 0.9743 - precision_m: 0.9743 - recall_m: 0.9743 - val_loss: 0.1654 - val_acc: 0.9543 - val_f1_m: 0.9572 - val_precision_m: 0.9572 - val_recall_m: 0.9572
# Epoch 104/300
# 45/45 - 8s - loss: 0.0782 - acc: 0.9725 - f1_m: 0.9725 - precision_m: 0.9725 - recall_m: 0.9725 - val_loss: 0.2246 - val_acc: 0.9571 - val_f1_m: 0.9598 - val_precision_m: 0.9598 - val_recall_m: 0.9598
# Epoch 105/300
# 45/45 - 9s - loss: 0.0756 - acc: 0.9734 - f1_m: 0.9734 - precision_m: 0.9734 - recall_m: 0.9734 - val_loss: 0.2315 - val_acc: 0.9566 - val_f1_m: 0.9593 - val_precision_m: 0.9593 - val_recall_m: 0.9593
# Epoch 106/300
# 45/45 - 8s - loss: 0.0734 - acc: 0.9736 - f1_m: 0.9736 - precision_m: 0.9736 - recall_m: 0.9736 - val_loss: 0.4670 - val_acc: 0.9082 - val_f1_m: 0.9136 - val_precision_m: 0.9136 - val_recall_m: 0.9136
# Epoch 107/300
# 45/45 - 8s - loss: 0.0838 - acc: 0.9699 - f1_m: 0.9699 - precision_m: 0.9699 - recall_m: 0.9699 - val_loss: 0.3022 - val_acc: 0.9341 - val_f1_m: 0.9379 - val_precision_m: 0.9379 - val_recall_m: 0.9379
# Epoch 108/300
# 45/45 - 8s - loss: 0.0829 - acc: 0.9715 - f1_m: 0.9715 - precision_m: 0.9715 - recall_m: 0.9715 - val_loss: 0.3213 - val_acc: 0.9503 - val_f1_m: 0.9534 - val_precision_m: 0.9534 - val_recall_m: 0.9534
# Epoch 109/300
# 45/45 - 8s - loss: 0.0788 - acc: 0.9727 - f1_m: 0.9727 - precision_m: 0.9727 - recall_m: 0.9727 - val_loss: 0.3601 - val_acc: 0.9535 - val_f1_m: 0.9563 - val_precision_m: 0.9563 - val_recall_m: 0.9563
# Epoch 110/300
# 45/45 - 8s - loss: 0.0829 - acc: 0.9713 - f1_m: 0.9713 - precision_m: 0.9713 - recall_m: 0.9713 - val_loss: 0.2614 - val_acc: 0.9542 - val_f1_m: 0.9570 - val_precision_m: 0.9570 - val_recall_m: 0.9570
# Epoch 111/300
# 45/45 - 9s - loss: 0.0737 - acc: 0.9749 - f1_m: 0.9749 - precision_m: 0.9749 - recall_m: 0.9749 - val_loss: 0.1933 - val_acc: 0.9556 - val_f1_m: 0.9583 - val_precision_m: 0.9583 - val_recall_m: 0.9583
# Epoch 112/300
# 45/45 - 8s - loss: 0.0834 - acc: 0.9711 - f1_m: 0.9711 - precision_m: 0.9711 - recall_m: 0.9711 - val_loss: 0.3569 - val_acc: 0.9383 - val_f1_m: 0.9420 - val_precision_m: 0.9420 - val_recall_m: 0.9420
# Epoch 113/300
# 45/45 - 8s - loss: 0.0743 - acc: 0.9737 - f1_m: 0.9737 - precision_m: 0.9737 - recall_m: 0.9737 - val_loss: 0.2742 - val_acc: 0.9574 - val_f1_m: 0.9601 - val_precision_m: 0.9601 - val_recall_m: 0.9601
# Epoch 114/300
# 45/45 - 8s - loss: 0.0792 - acc: 0.9729 - f1_m: 0.9729 - precision_m: 0.9729 - recall_m: 0.9729 - val_loss: 0.2875 - val_acc: 0.9497 - val_f1_m: 0.9528 - val_precision_m: 0.9528 - val_recall_m: 0.9528
# Epoch 115/300
# 45/45 - 8s - loss: 0.0747 - acc: 0.9738 - f1_m: 0.9738 - precision_m: 0.9738 - recall_m: 0.9738 - val_loss: 0.2616 - val_acc: 0.9557 - val_f1_m: 0.9585 - val_precision_m: 0.9585 - val_recall_m: 0.9585
# Epoch 116/300
# 45/45 - 9s - loss: 0.0711 - acc: 0.9743 - f1_m: 0.9743 - precision_m: 0.9743 - recall_m: 0.9743 - val_loss: 0.1708 - val_acc: 0.9530 - val_f1_m: 0.9560 - val_precision_m: 0.9560 - val_recall_m: 0.9560
# Epoch 117/300
# 45/45 - 8s - loss: 0.0733 - acc: 0.9743 - f1_m: 0.9743 - precision_m: 0.9743 - recall_m: 0.9743 - val_loss: 0.3257 - val_acc: 0.9217 - val_f1_m: 0.9264 - val_precision_m: 0.9264 - val_recall_m: 0.9264
# Epoch 118/300
# 45/45 - 8s - loss: 0.0756 - acc: 0.9735 - f1_m: 0.9735 - precision_m: 0.9735 - recall_m: 0.9735 - val_loss: 0.4541 - val_acc: 0.8947 - val_f1_m: 0.8998 - val_precision_m: 0.8998 - val_recall_m: 0.8998
# Epoch 119/300
# 45/45 - 8s - loss: 0.0807 - acc: 0.9711 - f1_m: 0.9711 - precision_m: 0.9711 - recall_m: 0.9711 - val_loss: 0.1841 - val_acc: 0.9488 - val_f1_m: 0.9520 - val_precision_m: 0.9520 - val_recall_m: 0.9520
# Epoch 120/300
# 45/45 - 8s - loss: 0.0923 - acc: 0.9669 - f1_m: 0.9669 - precision_m: 0.9669 - recall_m: 0.9669 - val_loss: 0.4019 - val_acc: 0.9212 - val_f1_m: 0.9260 - val_precision_m: 0.9260 - val_recall_m: 0.9260
# Epoch 121/300
# 45/45 - 9s - loss: 0.0858 - acc: 0.9702 - f1_m: 0.9702 - precision_m: 0.9702 - recall_m: 0.9702 - val_loss: 0.3882 - val_acc: 0.9344 - val_f1_m: 0.9384 - val_precision_m: 0.9384 - val_recall_m: 0.9384
# Epoch 122/300
# 45/45 - 8s - loss: 0.0753 - acc: 0.9732 - f1_m: 0.9732 - precision_m: 0.9732 - recall_m: 0.9732 - val_loss: 0.4306 - val_acc: 0.9073 - val_f1_m: 0.9121 - val_precision_m: 0.9121 - val_recall_m: 0.9121
# Epoch 123/300
# 45/45 - 9s - loss: 0.0748 - acc: 0.9734 - f1_m: 0.9734 - precision_m: 0.9734 - recall_m: 0.9734 - val_loss: 0.2935 - val_acc: 0.9526 - val_f1_m: 0.9554 - val_precision_m: 0.9554 - val_recall_m: 0.9554
# Epoch 124/300
# 45/45 - 9s - loss: 0.0772 - acc: 0.9732 - f1_m: 0.9732 - precision_m: 0.9732 - recall_m: 0.9732 - val_loss: 0.4295 - val_acc: 0.9358 - val_f1_m: 0.9398 - val_precision_m: 0.9398 - val_recall_m: 0.9398
# Epoch 125/300
# 45/45 - 8s - loss: 0.0761 - acc: 0.9730 - f1_m: 0.9730 - precision_m: 0.9730 - recall_m: 0.9730 - val_loss: 0.2597 - val_acc: 0.9551 - val_f1_m: 0.9579 - val_precision_m: 0.9579 - val_recall_m: 0.9579
# Epoch 126/300
# 45/45 - 9s - loss: 0.0776 - acc: 0.9730 - f1_m: 0.9730 - precision_m: 0.9730 - recall_m: 0.9730 - val_loss: 0.3983 - val_acc: 0.8681 - val_f1_m: 0.8734 - val_precision_m: 0.8734 - val_recall_m: 0.8734
# Epoch 127/300
# 45/45 - 9s - loss: 0.0843 - acc: 0.9704 - f1_m: 0.9704 - precision_m: 0.9704 - recall_m: 0.9704 - val_loss: 0.4883 - val_acc: 0.8954 - val_f1_m: 0.9012 - val_precision_m: 0.9012 - val_recall_m: 0.9012
# Epoch 128/300
# 45/45 - 9s - loss: 0.0740 - acc: 0.9736 - f1_m: 0.9736 - precision_m: 0.9736 - recall_m: 0.9736 - val_loss: 0.3909 - val_acc: 0.9416 - val_f1_m: 0.9453 - val_precision_m: 0.9453 - val_recall_m: 0.9453
# Epoch 129/300
# 45/45 - 9s - loss: 0.0753 - acc: 0.9735 - f1_m: 0.9735 - precision_m: 0.9735 - recall_m: 0.9735 - val_loss: 0.4524 - val_acc: 0.9182 - val_f1_m: 0.9226 - val_precision_m: 0.9226 - val_recall_m: 0.9226
# Epoch 130/300
# 45/45 - 9s - loss: 0.0939 - acc: 0.9681 - f1_m: 0.9681 - precision_m: 0.9681 - recall_m: 0.9681 - val_loss: 0.1745 - val_acc: 0.9537 - val_f1_m: 0.9566 - val_precision_m: 0.9566 - val_recall_m: 0.9566
# Epoch 131/300
# 45/45 - 9s - loss: 0.0818 - acc: 0.9714 - f1_m: 0.9714 - precision_m: 0.9714 - recall_m: 0.9714 - val_loss: 0.2752 - val_acc: 0.9530 - val_f1_m: 0.9559 - val_precision_m: 0.9559 - val_recall_m: 0.9559
# Epoch 132/300
# 45/45 - 9s - loss: 0.0741 - acc: 0.9738 - f1_m: 0.9738 - precision_m: 0.9738 - recall_m: 0.9738 - val_loss: 0.2359 - val_acc: 0.9588 - val_f1_m: 0.9613 - val_precision_m: 0.9613 - val_recall_m: 0.9613
# Epoch 133/300
# 45/45 - 8s - loss: 0.0694 - acc: 0.9755 - f1_m: 0.9755 - precision_m: 0.9755 - recall_m: 0.9755 - val_loss: 0.2478 - val_acc: 0.9559 - val_f1_m: 0.9586 - val_precision_m: 0.9586 - val_recall_m: 0.9586
# Epoch 134/300
# 45/45 - 8s - loss: 0.0804 - acc: 0.9723 - f1_m: 0.9723 - precision_m: 0.9723 - recall_m: 0.9723 - val_loss: 0.3814 - val_acc: 0.9433 - val_f1_m: 0.9469 - val_precision_m: 0.9469 - val_recall_m: 0.9469
# Epoch 135/300
# 45/45 - 8s - loss: 0.0744 - acc: 0.9737 - f1_m: 0.9737 - precision_m: 0.9737 - recall_m: 0.9737 - val_loss: 0.3489 - val_acc: 0.9434 - val_f1_m: 0.9468 - val_precision_m: 0.9468 - val_recall_m: 0.9468
# Epoch 136/300
# 45/45 - 9s - loss: 0.0734 - acc: 0.9734 - f1_m: 0.9734 - precision_m: 0.9734 - recall_m: 0.9734 - val_loss: 0.3771 - val_acc: 0.9445 - val_f1_m: 0.9479 - val_precision_m: 0.9479 - val_recall_m: 0.9479
# Epoch 137/300
# 45/45 - 9s - loss: 0.0679 - acc: 0.9760 - f1_m: 0.9760 - precision_m: 0.9760 - recall_m: 0.9760 - val_loss: 0.2543 - val_acc: 0.9445 - val_f1_m: 0.9480 - val_precision_m: 0.9480 - val_recall_m: 0.9480
# Epoch 138/300
# 45/45 - 9s - loss: 0.0711 - acc: 0.9747 - f1_m: 0.9747 - precision_m: 0.9747 - recall_m: 0.9747 - val_loss: 0.1820 - val_acc: 0.9575 - val_f1_m: 0.9602 - val_precision_m: 0.9602 - val_recall_m: 0.9602
# Epoch 139/300
# 45/45 - 9s - loss: 0.0715 - acc: 0.9740 - f1_m: 0.9740 - precision_m: 0.9740 - recall_m: 0.9740 - val_loss: 0.2782 - val_acc: 0.9554 - val_f1_m: 0.9581 - val_precision_m: 0.9581 - val_recall_m: 0.9581
# Epoch 140/300
# 45/45 - 9s - loss: 0.0705 - acc: 0.9755 - f1_m: 0.9755 - precision_m: 0.9755 - recall_m: 0.9755 - val_loss: 0.3013 - val_acc: 0.9499 - val_f1_m: 0.9530 - val_precision_m: 0.9530 - val_recall_m: 0.9530
# Epoch 141/300
# 45/45 - 9s - loss: 0.0680 - acc: 0.9756 - f1_m: 0.9756 - precision_m: 0.9756 - recall_m: 0.9756 - val_loss: 0.1672 - val_acc: 0.9559 - val_f1_m: 0.9586 - val_precision_m: 0.9586 - val_recall_m: 0.9586
# Epoch 142/300
# 45/45 - 9s - loss: 0.0676 - acc: 0.9755 - f1_m: 0.9755 - precision_m: 0.9755 - recall_m: 0.9755 - val_loss: 0.5102 - val_acc: 0.8936 - val_f1_m: 0.8998 - val_precision_m: 0.8998 - val_recall_m: 0.8998
# Epoch 143/300
# 45/45 - 8s - loss: 0.0643 - acc: 0.9762 - f1_m: 0.9762 - precision_m: 0.9762 - recall_m: 0.9762 - val_loss: 0.4779 - val_acc: 0.8991 - val_f1_m: 0.9054 - val_precision_m: 0.9054 - val_recall_m: 0.9054
# Epoch 144/300
# 45/45 - 8s - loss: 0.0715 - acc: 0.9746 - f1_m: 0.9746 - precision_m: 0.9746 - recall_m: 0.9746 - val_loss: 0.2567 - val_acc: 0.9469 - val_f1_m: 0.9501 - val_precision_m: 0.9501 - val_recall_m: 0.9501
# Epoch 145/300
# 45/45 - 8s - loss: 0.0678 - acc: 0.9759 - f1_m: 0.9759 - precision_m: 0.9759 - recall_m: 0.9759 - val_loss: 0.2591 - val_acc: 0.9485 - val_f1_m: 0.9516 - val_precision_m: 0.9516 - val_recall_m: 0.9516
# Epoch 146/300
# 45/45 - 8s - loss: 0.0679 - acc: 0.9756 - f1_m: 0.9756 - precision_m: 0.9756 - recall_m: 0.9756 - val_loss: 0.3938 - val_acc: 0.9359 - val_f1_m: 0.9399 - val_precision_m: 0.9399 - val_recall_m: 0.9399
# Epoch 147/300
# 45/45 - 8s - loss: 0.0654 - acc: 0.9767 - f1_m: 0.9767 - precision_m: 0.9767 - recall_m: 0.9767 - val_loss: 0.2428 - val_acc: 0.9557 - val_f1_m: 0.9584 - val_precision_m: 0.9584 - val_recall_m: 0.9584
# Epoch 148/300
# 45/45 - 8s - loss: 0.0683 - acc: 0.9752 - f1_m: 0.9752 - precision_m: 0.9752 - recall_m: 0.9752 - val_loss: 0.4948 - val_acc: 0.8859 - val_f1_m: 0.8902 - val_precision_m: 0.8902 - val_recall_m: 0.8902
# Epoch 149/300
# 45/45 - 8s - loss: 0.0657 - acc: 0.9759 - f1_m: 0.9759 - precision_m: 0.9759 - recall_m: 0.9759 - val_loss: 0.1634 - val_acc: 0.9583 - val_f1_m: 0.9609 - val_precision_m: 0.9609 - val_recall_m: 0.9609
# Epoch 150/300
# 45/45 - 8s - loss: 0.0619 - acc: 0.9780 - f1_m: 0.9780 - precision_m: 0.9780 - recall_m: 0.9780 - val_loss: 0.1724 - val_acc: 0.9583 - val_f1_m: 0.9609 - val_precision_m: 0.9609 - val_recall_m: 0.9609
# Epoch 151/300
# 45/45 - 8s - loss: 0.0690 - acc: 0.9743 - f1_m: 0.9743 - precision_m: 0.9743 - recall_m: 0.9743 - val_loss: 0.3334 - val_acc: 0.9570 - val_f1_m: 0.9597 - val_precision_m: 0.9597 - val_recall_m: 0.9597
# Epoch 152/300
# 45/45 - 9s - loss: 0.0699 - acc: 0.9743 - f1_m: 0.9743 - precision_m: 0.9743 - recall_m: 0.9743 - val_loss: 0.4156 - val_acc: 0.9481 - val_f1_m: 0.9513 - val_precision_m: 0.9513 - val_recall_m: 0.9513
# Epoch 153/300
# 45/45 - 8s - loss: 0.0713 - acc: 0.9748 - f1_m: 0.9748 - precision_m: 0.9748 - recall_m: 0.9748 - val_loss: 0.2767 - val_acc: 0.9355 - val_f1_m: 0.9387 - val_precision_m: 0.9387 - val_recall_m: 0.9387
# Epoch 154/300
# 45/45 - 9s - loss: 0.0688 - acc: 0.9749 - f1_m: 0.9749 - precision_m: 0.9749 - recall_m: 0.9749 - val_loss: 0.2698 - val_acc: 0.9322 - val_f1_m: 0.9360 - val_precision_m: 0.9360 - val_recall_m: 0.9360
# Epoch 155/300
# 45/45 - 8s - loss: 0.0641 - acc: 0.9771 - f1_m: 0.9771 - precision_m: 0.9771 - recall_m: 0.9771 - val_loss: 0.2273 - val_acc: 0.9498 - val_f1_m: 0.9528 - val_precision_m: 0.9528 - val_recall_m: 0.9528
# Epoch 156/300
# 45/45 - 9s - loss: 0.0681 - acc: 0.9755 - f1_m: 0.9755 - precision_m: 0.9755 - recall_m: 0.9755 - val_loss: 0.3469 - val_acc: 0.8829 - val_f1_m: 0.8902 - val_precision_m: 0.8902 - val_recall_m: 0.8902
# Epoch 157/300
# 45/45 - 9s - loss: 0.0653 - acc: 0.9773 - f1_m: 0.9773 - precision_m: 0.9773 - recall_m: 0.9773 - val_loss: 0.3282 - val_acc: 0.9330 - val_f1_m: 0.9370 - val_precision_m: 0.9370 - val_recall_m: 0.9370
# Epoch 158/300
# 45/45 - 9s - loss: 0.0690 - acc: 0.9754 - f1_m: 0.9754 - precision_m: 0.9754 - recall_m: 0.9754 - val_loss: 0.1813 - val_acc: 0.9583 - val_f1_m: 0.9609 - val_precision_m: 0.9609 - val_recall_m: 0.9609
# Epoch 159/300
# 45/45 - 8s - loss: 0.0677 - acc: 0.9756 - f1_m: 0.9756 - precision_m: 0.9756 - recall_m: 0.9756 - val_loss: 0.2951 - val_acc: 0.9480 - val_f1_m: 0.9512 - val_precision_m: 0.9512 - val_recall_m: 0.9512
# Epoch 160/300
# 45/45 - 9s - loss: 0.0731 - acc: 0.9735 - f1_m: 0.9735 - precision_m: 0.9735 - recall_m: 0.9735 - val_loss: 0.4712 - val_acc: 0.9161 - val_f1_m: 0.9213 - val_precision_m: 0.9213 - val_recall_m: 0.9213
# Epoch 161/300
# 45/45 - 9s - loss: 0.0672 - acc: 0.9754 - f1_m: 0.9754 - precision_m: 0.9754 - recall_m: 0.9754 - val_loss: 0.3563 - val_acc: 0.9292 - val_f1_m: 0.9336 - val_precision_m: 0.9336 - val_recall_m: 0.9336
# Epoch 162/300
# 45/45 - 9s - loss: 0.0686 - acc: 0.9758 - f1_m: 0.9758 - precision_m: 0.9758 - recall_m: 0.9758 - val_loss: 0.3692 - val_acc: 0.9182 - val_f1_m: 0.9222 - val_precision_m: 0.9222 - val_recall_m: 0.9222
# Epoch 163/300
# 45/45 - 9s - loss: 0.0623 - acc: 0.9774 - f1_m: 0.9774 - precision_m: 0.9774 - recall_m: 0.9774 - val_loss: 0.3828 - val_acc: 0.9356 - val_f1_m: 0.9394 - val_precision_m: 0.9394 - val_recall_m: 0.9394
# Epoch 164/300
# 45/45 - 9s - loss: 0.0640 - acc: 0.9764 - f1_m: 0.9764 - precision_m: 0.9764 - recall_m: 0.9764 - val_loss: 0.2859 - val_acc: 0.9568 - val_f1_m: 0.9595 - val_precision_m: 0.9595 - val_recall_m: 0.9595
# Epoch 165/300
# 45/45 - 9s - loss: 0.0600 - acc: 0.9788 - f1_m: 0.9788 - precision_m: 0.9788 - recall_m: 0.9788 - val_loss: 0.2907 - val_acc: 0.9536 - val_f1_m: 0.9565 - val_precision_m: 0.9565 - val_recall_m: 0.9565
# Epoch 166/300
# 45/45 - 9s - loss: 0.0615 - acc: 0.9778 - f1_m: 0.9778 - precision_m: 0.9778 - recall_m: 0.9778 - val_loss: 0.3239 - val_acc: 0.9469 - val_f1_m: 0.9502 - val_precision_m: 0.9502 - val_recall_m: 0.9502
# Epoch 167/300
# 45/45 - 9s - loss: 0.0644 - acc: 0.9771 - f1_m: 0.9771 - precision_m: 0.9771 - recall_m: 0.9771 - val_loss: 0.5678 - val_acc: 0.8666 - val_f1_m: 0.8727 - val_precision_m: 0.8727 - val_recall_m: 0.8727
# Epoch 168/300
# 45/45 - 9s - loss: 0.0608 - acc: 0.9776 - f1_m: 0.9776 - precision_m: 0.9776 - recall_m: 0.9776 - val_loss: 0.3639 - val_acc: 0.9378 - val_f1_m: 0.9413 - val_precision_m: 0.9413 - val_recall_m: 0.9413
# Epoch 169/300
# 45/45 - 9s - loss: 0.0614 - acc: 0.9782 - f1_m: 0.9782 - precision_m: 0.9782 - recall_m: 0.9782 - val_loss: 0.2848 - val_acc: 0.9526 - val_f1_m: 0.9555 - val_precision_m: 0.9555 - val_recall_m: 0.9555
# Epoch 170/300
# 45/45 - 8s - loss: 0.0761 - acc: 0.9731 - f1_m: 0.9731 - precision_m: 0.9731 - recall_m: 0.9731 - val_loss: 0.8086 - val_acc: 0.8006 - val_f1_m: 0.8113 - val_precision_m: 0.8113 - val_recall_m: 0.8113
# Epoch 171/300
# 45/45 - 9s - loss: 0.0697 - acc: 0.9748 - f1_m: 0.9748 - precision_m: 0.9748 - recall_m: 0.9748 - val_loss: 0.1989 - val_acc: 0.9593 - val_f1_m: 0.9618 - val_precision_m: 0.9618 - val_recall_m: 0.9618
# Epoch 172/300
# 45/45 - 9s - loss: 0.0592 - acc: 0.9785 - f1_m: 0.9785 - precision_m: 0.9785 - recall_m: 0.9785 - val_loss: 0.1972 - val_acc: 0.9559 - val_f1_m: 0.9585 - val_precision_m: 0.9585 - val_recall_m: 0.9585
# Epoch 173/300
# 45/45 - 9s - loss: 0.0668 - acc: 0.9758 - f1_m: 0.9758 - precision_m: 0.9758 - recall_m: 0.9758 - val_loss: 0.2188 - val_acc: 0.9600 - val_f1_m: 0.9625 - val_precision_m: 0.9625 - val_recall_m: 0.9625
# Epoch 174/300
# 45/45 - 8s - loss: 0.0599 - acc: 0.9778 - f1_m: 0.9778 - precision_m: 0.9778 - recall_m: 0.9778 - val_loss: 0.2043 - val_acc: 0.9579 - val_f1_m: 0.9606 - val_precision_m: 0.9606 - val_recall_m: 0.9606
# Epoch 175/300
# 45/45 - 9s - loss: 0.0771 - acc: 0.9736 - f1_m: 0.9736 - precision_m: 0.9736 - recall_m: 0.9736 - val_loss: 0.2247 - val_acc: 0.9386 - val_f1_m: 0.9424 - val_precision_m: 0.9424 - val_recall_m: 0.9424
# Epoch 176/300
# 45/45 - 9s - loss: 0.0619 - acc: 0.9778 - f1_m: 0.9778 - precision_m: 0.9778 - recall_m: 0.9778 - val_loss: 0.1890 - val_acc: 0.9599 - val_f1_m: 0.9624 - val_precision_m: 0.9624 - val_recall_m: 0.9624
# Epoch 177/300
# 45/45 - 8s - loss: 0.0593 - acc: 0.9783 - f1_m: 0.9783 - precision_m: 0.9783 - recall_m: 0.9783 - val_loss: 0.2546 - val_acc: 0.9574 - val_f1_m: 0.9601 - val_precision_m: 0.9601 - val_recall_m: 0.9601
# Epoch 178/300
# 45/45 - 8s - loss: 0.0589 - acc: 0.9785 - f1_m: 0.9785 - precision_m: 0.9785 - recall_m: 0.9785 - val_loss: 0.2304 - val_acc: 0.9585 - val_f1_m: 0.9611 - val_precision_m: 0.9611 - val_recall_m: 0.9611
# Epoch 179/300
# 45/45 - 8s - loss: 0.0668 - acc: 0.9758 - f1_m: 0.9758 - precision_m: 0.9758 - recall_m: 0.9758 - val_loss: 0.2052 - val_acc: 0.9584 - val_f1_m: 0.9610 - val_precision_m: 0.9610 - val_recall_m: 0.9610
# Epoch 180/300
# 45/45 - 8s - loss: 0.0591 - acc: 0.9792 - f1_m: 0.9792 - precision_m: 0.9792 - recall_m: 0.9792 - val_loss: 0.2888 - val_acc: 0.9505 - val_f1_m: 0.9536 - val_precision_m: 0.9536 - val_recall_m: 0.9536
# Epoch 181/300
# 45/45 - 8s - loss: 0.0682 - acc: 0.9753 - f1_m: 0.9753 - precision_m: 0.9753 - recall_m: 0.9753 - val_loss: 0.3722 - val_acc: 0.9474 - val_f1_m: 0.9507 - val_precision_m: 0.9507 - val_recall_m: 0.9507
# Epoch 182/300
# 45/45 - 8s - loss: 0.0606 - acc: 0.9791 - f1_m: 0.9791 - precision_m: 0.9791 - recall_m: 0.9791 - val_loss: 0.2141 - val_acc: 0.9540 - val_f1_m: 0.9568 - val_precision_m: 0.9568 - val_recall_m: 0.9568
# Epoch 183/300
# 45/45 - 8s - loss: 0.0627 - acc: 0.9774 - f1_m: 0.9774 - precision_m: 0.9774 - recall_m: 0.9774 - val_loss: 0.4647 - val_acc: 0.9018 - val_f1_m: 0.9076 - val_precision_m: 0.9076 - val_recall_m: 0.9076
# Epoch 184/300
# 45/45 - 8s - loss: 0.0588 - acc: 0.9790 - f1_m: 0.9790 - precision_m: 0.9790 - recall_m: 0.9790 - val_loss: 0.3534 - val_acc: 0.9368 - val_f1_m: 0.9403 - val_precision_m: 0.9403 - val_recall_m: 0.9403
# Epoch 185/300
# 45/45 - 8s - loss: 0.0640 - acc: 0.9770 - f1_m: 0.9770 - precision_m: 0.9770 - recall_m: 0.9770 - val_loss: 0.2985 - val_acc: 0.9513 - val_f1_m: 0.9542 - val_precision_m: 0.9542 - val_recall_m: 0.9542
# Epoch 186/300
# 45/45 - 8s - loss: 0.0600 - acc: 0.9784 - f1_m: 0.9784 - precision_m: 0.9784 - recall_m: 0.9784 - val_loss: 0.2740 - val_acc: 0.9210 - val_f1_m: 0.9255 - val_precision_m: 0.9255 - val_recall_m: 0.9255
# Epoch 187/300
# 45/45 - 8s - loss: 0.0610 - acc: 0.9774 - f1_m: 0.9774 - precision_m: 0.9774 - recall_m: 0.9774 - val_loss: 0.3780 - val_acc: 0.9471 - val_f1_m: 0.9503 - val_precision_m: 0.9503 - val_recall_m: 0.9503
# Epoch 188/300
# 45/45 - 8s - loss: 0.0617 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 0.3961 - val_acc: 0.9451 - val_f1_m: 0.9485 - val_precision_m: 0.9485 - val_recall_m: 0.9485
# Epoch 189/300
# 45/45 - 8s - loss: 0.0582 - acc: 0.9789 - f1_m: 0.9789 - precision_m: 0.9789 - recall_m: 0.9789 - val_loss: 0.1876 - val_acc: 0.9478 - val_f1_m: 0.9511 - val_precision_m: 0.9511 - val_recall_m: 0.9511
# Epoch 190/300
# 45/45 - 8s - loss: 0.0558 - acc: 0.9801 - f1_m: 0.9801 - precision_m: 0.9801 - recall_m: 0.9801 - val_loss: 0.4246 - val_acc: 0.9354 - val_f1_m: 0.9394 - val_precision_m: 0.9394 - val_recall_m: 0.9394
# Epoch 191/300
# 45/45 - 8s - loss: 0.0540 - acc: 0.9804 - f1_m: 0.9804 - precision_m: 0.9804 - recall_m: 0.9804 - val_loss: 0.2360 - val_acc: 0.9579 - val_f1_m: 0.9605 - val_precision_m: 0.9605 - val_recall_m: 0.9605
# Epoch 192/300
# 45/45 - 8s - loss: 0.0601 - acc: 0.9789 - f1_m: 0.9789 - precision_m: 0.9789 - recall_m: 0.9789 - val_loss: 0.5628 - val_acc: 0.9066 - val_f1_m: 0.9124 - val_precision_m: 0.9124 - val_recall_m: 0.9124
# Epoch 193/300
# 45/45 - 8s - loss: 0.0614 - acc: 0.9780 - f1_m: 0.9780 - precision_m: 0.9780 - recall_m: 0.9780 - val_loss: 0.2942 - val_acc: 0.9523 - val_f1_m: 0.9553 - val_precision_m: 0.9553 - val_recall_m: 0.9553
# Epoch 194/300
# 45/45 - 8s - loss: 0.0594 - acc: 0.9786 - f1_m: 0.9786 - precision_m: 0.9786 - recall_m: 0.9786 - val_loss: 0.3432 - val_acc: 0.9485 - val_f1_m: 0.9517 - val_precision_m: 0.9517 - val_recall_m: 0.9517
# Epoch 195/300
# 45/45 - 8s - loss: 0.0583 - acc: 0.9791 - f1_m: 0.9791 - precision_m: 0.9791 - recall_m: 0.9791 - val_loss: 0.1743 - val_acc: 0.9527 - val_f1_m: 0.9556 - val_precision_m: 0.9556 - val_recall_m: 0.9556
# Epoch 196/300
# 45/45 - 8s - loss: 0.0581 - acc: 0.9793 - f1_m: 0.9793 - precision_m: 0.9793 - recall_m: 0.9793 - val_loss: 0.3282 - val_acc: 0.9543 - val_f1_m: 0.9572 - val_precision_m: 0.9572 - val_recall_m: 0.9572
# Epoch 197/300
# 45/45 - 8s - loss: 0.0532 - acc: 0.9810 - f1_m: 0.9810 - precision_m: 0.9810 - recall_m: 0.9810 - val_loss: 0.1989 - val_acc: 0.9564 - val_f1_m: 0.9591 - val_precision_m: 0.9591 - val_recall_m: 0.9591
# Epoch 198/300
# 45/45 - 8s - loss: 0.0513 - acc: 0.9814 - f1_m: 0.9814 - precision_m: 0.9814 - recall_m: 0.9814 - val_loss: 0.2557 - val_acc: 0.9579 - val_f1_m: 0.9605 - val_precision_m: 0.9605 - val_recall_m: 0.9605
# Epoch 199/300
# 45/45 - 8s - loss: 0.0561 - acc: 0.9795 - f1_m: 0.9795 - precision_m: 0.9795 - recall_m: 0.9795 - val_loss: 0.2325 - val_acc: 0.9423 - val_f1_m: 0.9457 - val_precision_m: 0.9457 - val_recall_m: 0.9457
# Epoch 200/300
# 45/45 - 8s - loss: 0.0545 - acc: 0.9806 - f1_m: 0.9806 - precision_m: 0.9806 - recall_m: 0.9806 - val_loss: 0.3414 - val_acc: 0.9379 - val_f1_m: 0.9415 - val_precision_m: 0.9415 - val_recall_m: 0.9415
# Epoch 201/300
# 45/45 - 9s - loss: 0.0546 - acc: 0.9801 - f1_m: 0.9801 - precision_m: 0.9801 - recall_m: 0.9801 - val_loss: 0.1961 - val_acc: 0.9411 - val_f1_m: 0.9448 - val_precision_m: 0.9448 - val_recall_m: 0.9448
# Epoch 202/300
# 45/45 - 9s - loss: 0.0556 - acc: 0.9798 - f1_m: 0.9798 - precision_m: 0.9798 - recall_m: 0.9798 - val_loss: 0.1987 - val_acc: 0.9468 - val_f1_m: 0.9500 - val_precision_m: 0.9500 - val_recall_m: 0.9500
# Epoch 203/300
# 45/45 - 8s - loss: 0.0572 - acc: 0.9798 - f1_m: 0.9798 - precision_m: 0.9798 - recall_m: 0.9798 - val_loss: 0.2387 - val_acc: 0.9424 - val_f1_m: 0.9460 - val_precision_m: 0.9460 - val_recall_m: 0.9460
# Epoch 204/300
# 45/45 - 8s - loss: 0.0522 - acc: 0.9809 - f1_m: 0.9809 - precision_m: 0.9809 - recall_m: 0.9809 - val_loss: 0.3936 - val_acc: 0.9491 - val_f1_m: 0.9523 - val_precision_m: 0.9523 - val_recall_m: 0.9523
# Epoch 205/300
# 45/45 - 8s - loss: 0.0518 - acc: 0.9809 - f1_m: 0.9809 - precision_m: 0.9809 - recall_m: 0.9809 - val_loss: 0.3559 - val_acc: 0.9227 - val_f1_m: 0.9249 - val_precision_m: 0.9249 - val_recall_m: 0.9249
# Epoch 206/300
# 45/45 - 8s - loss: 0.0617 - acc: 0.9780 - f1_m: 0.9780 - precision_m: 0.9780 - recall_m: 0.9780 - val_loss: 0.2146 - val_acc: 0.9550 - val_f1_m: 0.9577 - val_precision_m: 0.9577 - val_recall_m: 0.9577
# Epoch 207/300
# 45/45 - 8s - loss: 0.0651 - acc: 0.9760 - f1_m: 0.9760 - precision_m: 0.9760 - recall_m: 0.9760 - val_loss: 0.2318 - val_acc: 0.9552 - val_f1_m: 0.9580 - val_precision_m: 0.9580 - val_recall_m: 0.9580
# Epoch 208/300
# 45/45 - 8s - loss: 0.0627 - acc: 0.9770 - f1_m: 0.9770 - precision_m: 0.9770 - recall_m: 0.9770 - val_loss: 0.3585 - val_acc: 0.9170 - val_f1_m: 0.9211 - val_precision_m: 0.9211 - val_recall_m: 0.9211
# Epoch 209/300
# 45/45 - 9s - loss: 0.0534 - acc: 0.9807 - f1_m: 0.9807 - precision_m: 0.9807 - recall_m: 0.9807 - val_loss: 0.4149 - val_acc: 0.9152 - val_f1_m: 0.9198 - val_precision_m: 0.9198 - val_recall_m: 0.9198
# Epoch 210/300
# 45/45 - 9s - loss: 0.0544 - acc: 0.9803 - f1_m: 0.9803 - precision_m: 0.9803 - recall_m: 0.9803 - val_loss: 0.2824 - val_acc: 0.9535 - val_f1_m: 0.9563 - val_precision_m: 0.9563 - val_recall_m: 0.9563
# Epoch 211/300
# 45/45 - 9s - loss: 0.0635 - acc: 0.9771 - f1_m: 0.9771 - precision_m: 0.9771 - recall_m: 0.9771 - val_loss: 0.3766 - val_acc: 0.9532 - val_f1_m: 0.9562 - val_precision_m: 0.9562 - val_recall_m: 0.9562
# Epoch 212/300
# 45/45 - 8s - loss: 0.0580 - acc: 0.9794 - f1_m: 0.9794 - precision_m: 0.9794 - recall_m: 0.9794 - val_loss: 0.2989 - val_acc: 0.9447 - val_f1_m: 0.9481 - val_precision_m: 0.9481 - val_recall_m: 0.9481
# Epoch 213/300
# 45/45 - 8s - loss: 0.0497 - acc: 0.9819 - f1_m: 0.9819 - precision_m: 0.9819 - recall_m: 0.9819 - val_loss: 0.3015 - val_acc: 0.9462 - val_f1_m: 0.9495 - val_precision_m: 0.9495 - val_recall_m: 0.9495
# Epoch 214/300
# 45/45 - 8s - loss: 0.0489 - acc: 0.9817 - f1_m: 0.9817 - precision_m: 0.9817 - recall_m: 0.9817 - val_loss: 0.2969 - val_acc: 0.9503 - val_f1_m: 0.9533 - val_precision_m: 0.9533 - val_recall_m: 0.9533
# Epoch 215/300
# 45/45 - 8s - loss: 0.0504 - acc: 0.9818 - f1_m: 0.9818 - precision_m: 0.9818 - recall_m: 0.9818 - val_loss: 0.2725 - val_acc: 0.9524 - val_f1_m: 0.9554 - val_precision_m: 0.9554 - val_recall_m: 0.9554
# Epoch 216/300
# 45/45 - 8s - loss: 0.0532 - acc: 0.9807 - f1_m: 0.9807 - precision_m: 0.9807 - recall_m: 0.9807 - val_loss: 0.3394 - val_acc: 0.9399 - val_f1_m: 0.9434 - val_precision_m: 0.9434 - val_recall_m: 0.9434
# Epoch 217/300
# 45/45 - 8s - loss: 0.0497 - acc: 0.9823 - f1_m: 0.9823 - precision_m: 0.9823 - recall_m: 0.9823 - val_loss: 0.3256 - val_acc: 0.9546 - val_f1_m: 0.9575 - val_precision_m: 0.9575 - val_recall_m: 0.9575
# Epoch 218/300
# 45/45 - 8s - loss: 0.0521 - acc: 0.9807 - f1_m: 0.9807 - precision_m: 0.9807 - recall_m: 0.9807 - val_loss: 0.2905 - val_acc: 0.9416 - val_f1_m: 0.9450 - val_precision_m: 0.9450 - val_recall_m: 0.9450
# Epoch 219/300
# 45/45 - 8s - loss: 0.0534 - acc: 0.9804 - f1_m: 0.9804 - precision_m: 0.9804 - recall_m: 0.9804 - val_loss: 0.2720 - val_acc: 0.9506 - val_f1_m: 0.9537 - val_precision_m: 0.9537 - val_recall_m: 0.9537
# Epoch 220/300
# 45/45 - 8s - loss: 0.0578 - acc: 0.9797 - f1_m: 0.9797 - precision_m: 0.9797 - recall_m: 0.9797 - val_loss: 0.5466 - val_acc: 0.8925 - val_f1_m: 0.8985 - val_precision_m: 0.8985 - val_recall_m: 0.8985
# Epoch 221/300
# 45/45 - 8s - loss: 0.0590 - acc: 0.9782 - f1_m: 0.9782 - precision_m: 0.9782 - recall_m: 0.9782 - val_loss: 0.2839 - val_acc: 0.9311 - val_f1_m: 0.9350 - val_precision_m: 0.9350 - val_recall_m: 0.9350
# Epoch 222/300
# 45/45 - 8s - loss: 0.0507 - acc: 0.9815 - f1_m: 0.9815 - precision_m: 0.9815 - recall_m: 0.9815 - val_loss: 0.3938 - val_acc: 0.9274 - val_f1_m: 0.9316 - val_precision_m: 0.9316 - val_recall_m: 0.9316
# Epoch 223/300
# ...
# Epoch 227/300
# 45/45 - 8s - loss: 0.0575 - acc: 0.9799 - f1_m: 0.9799 - precision_m: 0.9799 - recall_m: 0.9799 - val_loss: 0.2580 - val_acc: 0.9492 - val_f1_m: 0.9520 - val_precision_m: 0.9520 - val_recall_m: 0.9520
# Epoch 228/300
# 45/45 - 8s - loss: 0.0529 - acc: 0.9809 - f1_m: 0.9809 - precision_m: 0.9809 - recall_m: 0.9809 - val_loss: 0.5137 - val_acc: 0.8317 - val_f1_m: 0.8376 - val_precision_m: 0.8376 - val_recall_m: 0.8376
# Epoch 229/300
# 45/45 - 8s - loss: 0.0478 - acc: 0.9829 - f1_m: 0.9829 - precision_m: 0.9829 - recall_m: 0.9829 - val_loss: 0.2737 - val_acc: 0.9510 - val_f1_m: 0.9541 - val_precision_m: 0.9541 - val_recall_m: 0.9541
# Epoch 230/300
# 45/45 - 8s - loss: 0.0472 - acc: 0.9827 - f1_m: 0.9827 - precision_m: 0.9827 - recall_m: 0.9827 - val_loss: 0.2828 - val_acc: 0.9528 - val_f1_m: 0.9557 - val_precision_m: 0.9557 - val_recall_m: 0.9557
# Epoch 231/300
# 45/45 - 8s - loss: 0.0513 - acc: 0.9818 - f1_m: 0.9818 - precision_m: 0.9818 - recall_m: 0.9818 - val_loss: 0.2235 - val_acc: 0.9587 - val_f1_m: 0.9613 - val_precision_m: 0.9613 - val_recall_m: 0.9613
# Epoch 232/300
# 45/45 - 8s - loss: 0.0466 - acc: 0.9834 - f1_m: 0.9834 - precision_m: 0.9834 - recall_m: 0.9834 - val_loss: 0.3657 - val_acc: 0.9490 - val_f1_m: 0.9520 - val_precision_m: 0.9520 - val_recall_m: 0.9520
# Epoch 233/300
# 45/45 - 8s - loss: 0.0517 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 0.3670 - val_acc: 0.9335 - val_f1_m: 0.9375 - val_precision_m: 0.9375 - val_recall_m: 0.9375
# Epoch 234/300
# 45/45 - 8s - loss: 0.0494 - acc: 0.9820 - f1_m: 0.9820 - precision_m: 0.9820 - recall_m: 0.9820 - val_loss: 0.6547 - val_acc: 0.8552 - val_f1_m: 0.8612 - val_precision_m: 0.8612 - val_recall_m: 0.8612
# Epoch 235/300
# 45/45 - 8s - loss: 0.0459 - acc: 0.9832 - f1_m: 0.9832 - precision_m: 0.9832 - recall_m: 0.9832 - val_loss: 0.2449 - val_acc: 0.9558 - val_f1_m: 0.9585 - val_precision_m: 0.9585 - val_recall_m: 0.9585
# Epoch 236/300
# 45/45 - 8s - loss: 0.0523 - acc: 0.9815 - f1_m: 0.9815 - precision_m: 0.9815 - recall_m: 0.9815 - val_loss: 0.2728 - val_acc: 0.9584 - val_f1_m: 0.9610 - val_precision_m: 0.9610 - val_recall_m: 0.9610
# Epoch 237/300
# 45/45 - 9s - loss: 0.0533 - acc: 0.9807 - f1_m: 0.9807 - precision_m: 0.9807 - recall_m: 0.9807 - val_loss: 0.2057 - val_acc: 0.9405 - val_f1_m: 0.9442 - val_precision_m: 0.9442 - val_recall_m: 0.9442
# Epoch 238/300
# 45/45 - 9s - loss: 0.0485 - acc: 0.9823 - f1_m: 0.9823 - precision_m: 0.9823 - recall_m: 0.9823 - val_loss: 0.2116 - val_acc: 0.9562 - val_f1_m: 0.9589 - val_precision_m: 0.9589 - val_recall_m: 0.9589
# Epoch 239/300
# 45/45 - 8s - loss: 0.0540 - acc: 0.9798 - f1_m: 0.9798 - precision_m: 0.9798 - recall_m: 0.9798 - val_loss: 0.3003 - val_acc: 0.9538 - val_f1_m: 0.9567 - val_precision_m: 0.9567 - val_recall_m: 0.9567
# Epoch 240/300
# 45/45 - 8s - loss: 0.0500 - acc: 0.9817 - f1_m: 0.9817 - precision_m: 0.9817 - recall_m: 0.9817 - val_loss: 0.1994 - val_acc: 0.9539 - val_f1_m: 0.9568 - val_precision_m: 0.9568 - val_recall_m: 0.9568
# Epoch 241/300
# 45/45 - 9s - loss: 0.0442 - acc: 0.9841 - f1_m: 0.9841 - precision_m: 0.9841 - recall_m: 0.9841 - val_loss: 0.2681 - val_acc: 0.9594 - val_f1_m: 0.9620 - val_precision_m: 0.9620 - val_recall_m: 0.9620
# Epoch 242/300
# 45/45 - 8s - loss: 0.0496 - acc: 0.9820 - f1_m: 0.9820 - precision_m: 0.9820 - recall_m: 0.9820 - val_loss: 0.5565 - val_acc: 0.9233 - val_f1_m: 0.9278 - val_precision_m: 0.9278 - val_recall_m: 0.9278
# Epoch 243/300
# 45/45 - 8s - loss: 0.0494 - acc: 0.9824 - f1_m: 0.9824 - precision_m: 0.9824 - recall_m: 0.9824 - val_loss: 0.2759 - val_acc: 0.9551 - val_f1_m: 0.9579 - val_precision_m: 0.9579 - val_recall_m: 0.9579
# Epoch 244/300
# 45/45 - 8s - loss: 0.0444 - acc: 0.9836 - f1_m: 0.9836 - precision_m: 0.9836 - recall_m: 0.9836 - val_loss: 0.4143 - val_acc: 0.9115 - val_f1_m: 0.9163 - val_precision_m: 0.9163 - val_recall_m: 0.9163
# Epoch 245/300
# 45/45 - 8s - loss: 0.0495 - acc: 0.9816 - f1_m: 0.9816 - precision_m: 0.9816 - recall_m: 0.9816 - val_loss: 0.6593 - val_acc: 0.8656 - val_f1_m: 0.8727 - val_precision_m: 0.8727 - val_recall_m: 0.8727
# Epoch 246/300
# 45/45 - 8s - loss: 0.0453 - acc: 0.9833 - f1_m: 0.9833 - precision_m: 0.9833 - recall_m: 0.9833 - val_loss: 0.2301 - val_acc: 0.9579 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 247/300
# 45/45 - 8s - loss: 0.0416 - acc: 0.9851 - f1_m: 0.9851 - precision_m: 0.9851 - recall_m: 0.9851 - val_loss: 0.3277 - val_acc: 0.9518 - val_f1_m: 0.9548 - val_precision_m: 0.9548 - val_recall_m: 0.9548
# Epoch 248/300
# 45/45 - 8s - loss: 0.0416 - acc: 0.9849 - f1_m: 0.9849 - precision_m: 0.9849 - recall_m: 0.9849 - val_loss: 0.4495 - val_acc: 0.9210 - val_f1_m: 0.9248 - val_precision_m: 0.9248 - val_recall_m: 0.9248
# Epoch 249/300
# 45/45 - 8s - loss: 0.0519 - acc: 0.9802 - f1_m: 0.9802 - precision_m: 0.9802 - recall_m: 0.9802 - val_loss: 0.2228 - val_acc: 0.9465 - val_f1_m: 0.9497 - val_precision_m: 0.9497 - val_recall_m: 0.9497
# Epoch 250/300
# 45/45 - 8s - loss: 0.0541 - acc: 0.9813 - f1_m: 0.9813 - precision_m: 0.9813 - recall_m: 0.9813 - val_loss: 0.9229 - val_acc: 0.8039 - val_f1_m: 0.8135 - val_precision_m: 0.8135 - val_recall_m: 0.8135
# Epoch 251/300
# 45/45 - 8s - loss: 0.0532 - acc: 0.9802 - f1_m: 0.9802 - precision_m: 0.9802 - recall_m: 0.9802 - val_loss: 0.2220 - val_acc: 0.9454 - val_f1_m: 0.9487 - val_precision_m: 0.9487 - val_recall_m: 0.9487
# Epoch 252/300
# 45/45 - 8s - loss: 0.0473 - acc: 0.9827 - f1_m: 0.9827 - precision_m: 0.9827 - recall_m: 0.9827 - val_loss: 0.2331 - val_acc: 0.9321 - val_f1_m: 0.9364 - val_precision_m: 0.9364 - val_recall_m: 0.9364
# Epoch 253/300
# 45/45 - 8s - loss: 0.0482 - acc: 0.9826 - f1_m: 0.9826 - precision_m: 0.9826 - recall_m: 0.9826 - val_loss: 0.2572 - val_acc: 0.9410 - val_f1_m: 0.9446 - val_precision_m: 0.9446 - val_recall_m: 0.9446
# Epoch 254/300
# 45/45 - 8s - loss: 0.0468 - acc: 0.9832 - f1_m: 0.9832 - precision_m: 0.9832 - recall_m: 0.9832 - val_loss: 0.6450 - val_acc: 0.8050 - val_f1_m: 0.8135 - val_precision_m: 0.8135 - val_recall_m: 0.8135
# Epoch 255/300
# 45/45 - 8s - loss: 0.0492 - acc: 0.9819 - f1_m: 0.9819 - precision_m: 0.9819 - recall_m: 0.9819 - val_loss: 0.1861 - val_acc: 0.9485 - val_f1_m: 0.9517 - val_precision_m: 0.9517 - val_recall_m: 0.9517
# Epoch 256/300
# 45/45 - 8s - loss: 0.0432 - acc: 0.9842 - f1_m: 0.9842 - precision_m: 0.9842 - recall_m: 0.9842 - val_loss: 0.1885 - val_acc: 0.9521 - val_f1_m: 0.9550 - val_precision_m: 0.9550 - val_recall_m: 0.9550
# Epoch 257/300
# 45/45 - 8s - loss: 0.0444 - acc: 0.9838 - f1_m: 0.9838 - precision_m: 0.9838 - recall_m: 0.9838 - val_loss: 0.4177 - val_acc: 0.9184 - val_f1_m: 0.9232 - val_precision_m: 0.9232 - val_recall_m: 0.9232
# Epoch 258/300
# 45/45 - 8s - loss: 0.0462 - acc: 0.9833 - f1_m: 0.9833 - precision_m: 0.9833 - recall_m: 0.9833 - val_loss: 0.2906 - val_acc: 0.9597 - val_f1_m: 0.9622 - val_precision_m: 0.9622 - val_recall_m: 0.9622
# Epoch 259/300
# 45/45 - 8s - loss: 0.0465 - acc: 0.9831 - f1_m: 0.9831 - precision_m: 0.9831 - recall_m: 0.9831 - val_loss: 0.2666 - val_acc: 0.9062 - val_f1_m: 0.9120 - val_precision_m: 0.9120 - val_recall_m: 0.9120
# Epoch 260/300
# 45/45 - 8s - loss: 0.0603 - acc: 0.9773 - f1_m: 0.9773 - precision_m: 0.9773 - recall_m: 0.9773 - val_loss: 0.5356 - val_acc: 0.8952 - val_f1_m: 0.9014 - val_precision_m: 0.9014 - val_recall_m: 0.9014
# Epoch 261/300
# 45/45 - 8s - loss: 0.0532 - acc: 0.9802 - f1_m: 0.9802 - precision_m: 0.9802 - recall_m: 0.9802 - val_loss: 0.2028 - val_acc: 0.9586 - val_f1_m: 0.9612 - val_precision_m: 0.9612 - val_recall_m: 0.9612
# Epoch 262/300
# 45/45 - 8s - loss: 0.0489 - acc: 0.9828 - f1_m: 0.9828 - precision_m: 0.9828 - recall_m: 0.9828 - val_loss: 0.2599 - val_acc: 0.9530 - val_f1_m: 0.9559 - val_precision_m: 0.9559 - val_recall_m: 0.9559
# Epoch 263/300
# 45/45 - 9s - loss: 0.0467 - acc: 0.9826 - f1_m: 0.9826 - precision_m: 0.9826 - recall_m: 0.9826 - val_loss: 0.2396 - val_acc: 0.9443 - val_f1_m: 0.9476 - val_precision_m: 0.9476 - val_recall_m: 0.9476
# Epoch 264/300
# 45/45 - 8s - loss: 0.0449 - acc: 0.9840 - f1_m: 0.9840 - precision_m: 0.9840 - recall_m: 0.9840 - val_loss: 0.2247 - val_acc: 0.9583 - val_f1_m: 0.9609 - val_precision_m: 0.9609 - val_recall_m: 0.9609
# Epoch 265/300
# 45/45 - 8s - loss: 0.0434 - acc: 0.9842 - f1_m: 0.9842 - precision_m: 0.9842 - recall_m: 0.9842 - val_loss: 0.3072 - val_acc: 0.9437 - val_f1_m: 0.9472 - val_precision_m: 0.9472 - val_recall_m: 0.9472
# Epoch 266/300
# 45/45 - 8s - loss: 0.0428 - acc: 0.9847 - f1_m: 0.9847 - precision_m: 0.9847 - recall_m: 0.9847 - val_loss: 0.2491 - val_acc: 0.9551 - val_f1_m: 0.9579 - val_precision_m: 0.9579 - val_recall_m: 0.9579
# Epoch 267/300
# 45/45 - 8s - loss: 0.0462 - acc: 0.9831 - f1_m: 0.9831 - precision_m: 0.9831 - recall_m: 0.9831 - val_loss: 0.3715 - val_acc: 0.9338 - val_f1_m: 0.9378 - val_precision_m: 0.9378 - val_recall_m: 0.9378
# Epoch 268/300
# 45/45 - 9s - loss: 0.0392 - acc: 0.9864 - f1_m: 0.9864 - precision_m: 0.9864 - recall_m: 0.9864 - val_loss: 0.3940 - val_acc: 0.9435 - val_f1_m: 0.9470 - val_precision_m: 0.9470 - val_recall_m: 0.9470
# Epoch 269/300
# 45/45 - 8s - loss: 0.0520 - acc: 0.9817 - f1_m: 0.9817 - precision_m: 0.9817 - recall_m: 0.9817 - val_loss: 0.3440 - val_acc: 0.8912 - val_f1_m: 0.8972 - val_precision_m: 0.8972 - val_recall_m: 0.8972
# Epoch 270/300
# 45/45 - 8s - loss: 0.0592 - acc: 0.9776 - f1_m: 0.9776 - precision_m: 0.9776 - recall_m: 0.9776 - val_loss: 0.4277 - val_acc: 0.9414 - val_f1_m: 0.9450 - val_precision_m: 0.9450 - val_recall_m: 0.9450
# Epoch 271/300
# 45/45 - 8s - loss: 0.0487 - acc: 0.9821 - f1_m: 0.9821 - precision_m: 0.9821 - recall_m: 0.9821 - val_loss: 0.4282 - val_acc: 0.9070 - val_f1_m: 0.9118 - val_precision_m: 0.9118 - val_recall_m: 0.9118
# Epoch 272/300
# 45/45 - 9s - loss: 0.0458 - acc: 0.9825 - f1_m: 0.9825 - precision_m: 0.9825 - recall_m: 0.9825 - val_loss: 0.2685 - val_acc: 0.9601 - val_f1_m: 0.9626 - val_precision_m: 0.9626 - val_recall_m: 0.9626
# Epoch 273/300
# 45/45 - 8s - loss: 0.0388 - acc: 0.9860 - f1_m: 0.9860 - precision_m: 0.9860 - recall_m: 0.9860 - val_loss: 0.2123 - val_acc: 0.9390 - val_f1_m: 0.9429 - val_precision_m: 0.9429 - val_recall_m: 0.9429
# Epoch 274/300
# 45/45 - 9s - loss: 0.0468 - acc: 0.9831 - f1_m: 0.9831 - precision_m: 0.9831 - recall_m: 0.9831 - val_loss: 0.3600 - val_acc: 0.9094 - val_f1_m: 0.9138 - val_precision_m: 0.9138 - val_recall_m: 0.9138
# Epoch 275/300
# 45/45 - 9s - loss: 0.0482 - acc: 0.9833 - f1_m: 0.9833 - precision_m: 0.9833 - recall_m: 0.9833 - val_loss: 0.2316 - val_acc: 0.9551 - val_f1_m: 0.9578 - val_precision_m: 0.9578 - val_recall_m: 0.9578
# Epoch 276/300
# 45/45 - 8s - loss: 0.0423 - acc: 0.9839 - f1_m: 0.9839 - precision_m: 0.9839 - recall_m: 0.9839 - val_loss: 0.1963 - val_acc: 0.9565 - val_f1_m: 0.9592 - val_precision_m: 0.9592 - val_recall_m: 0.9592
# Epoch 277/300
# 45/45 - 8s - loss: 0.0388 - acc: 0.9863 - f1_m: 0.9863 - precision_m: 0.9863 - recall_m: 0.9863 - val_loss: 0.4310 - val_acc: 0.9187 - val_f1_m: 0.9229 - val_precision_m: 0.9229 - val_recall_m: 0.9229
# Epoch 278/300
# 45/45 - 9s - loss: 0.0422 - acc: 0.9845 - f1_m: 0.9845 - precision_m: 0.9845 - recall_m: 0.9845 - val_loss: 0.2045 - val_acc: 0.9567 - val_f1_m: 0.9594 - val_precision_m: 0.9594 - val_recall_m: 0.9594
# Epoch 279/300
# 45/45 - 8s - loss: 0.0380 - acc: 0.9864 - f1_m: 0.9864 - precision_m: 0.9864 - recall_m: 0.9864 - val_loss: 0.3219 - val_acc: 0.9519 - val_f1_m: 0.9549 - val_precision_m: 0.9549 - val_recall_m: 0.9549
# Epoch 280/300
# 45/45 - 9s - loss: 0.0430 - acc: 0.9842 - f1_m: 0.9842 - precision_m: 0.9842 - recall_m: 0.9842 - val_loss: 0.2538 - val_acc: 0.9587 - val_f1_m: 0.9613 - val_precision_m: 0.9613 - val_recall_m: 0.9613
# Epoch 281/300
# 45/45 - 8s - loss: 0.0407 - acc: 0.9848 - f1_m: 0.9848 - precision_m: 0.9848 - recall_m: 0.9848 - val_loss: 0.2014 - val_acc: 0.9542 - val_f1_m: 0.9571 - val_precision_m: 0.9571 - val_recall_m: 0.9571
# Epoch 282/300
# 45/45 - 8s - loss: 0.0434 - acc: 0.9833 - f1_m: 0.9833 - precision_m: 0.9833 - recall_m: 0.9833 - val_loss: 0.3355 - val_acc: 0.9542 - val_f1_m: 0.9570 - val_precision_m: 0.9570 - val_recall_m: 0.9570
# Epoch 283/300
# 45/45 - 8s - loss: 0.0348 - acc: 0.9879 - f1_m: 0.9879 - precision_m: 0.9879 - recall_m: 0.9879 - val_loss: 0.2668 - val_acc: 0.9527 - val_f1_m: 0.9556 - val_precision_m: 0.9556 - val_recall_m: 0.9556
# Epoch 284/300
# 45/45 - 9s - loss: 0.0405 - acc: 0.9856 - f1_m: 0.9856 - precision_m: 0.9856 - recall_m: 0.9856 - val_loss: 0.2582 - val_acc: 0.9344 - val_f1_m: 0.9382 - val_precision_m: 0.9382 - val_recall_m: 0.9382
# Epoch 285/300
# 45/45 - 8s - loss: 0.0391 - acc: 0.9862 - f1_m: 0.9862 - precision_m: 0.9862 - recall_m: 0.9862 - val_loss: 0.4212 - val_acc: 0.8607 - val_f1_m: 0.8674 - val_precision_m: 0.8674 - val_recall_m: 0.8674
# Epoch 286/300
# 45/45 - 9s - loss: 0.0398 - acc: 0.9852 - f1_m: 0.9852 - precision_m: 0.9852 - recall_m: 0.9852 - val_loss: 0.3031 - val_acc: 0.9597 - val_f1_m: 0.9622 - val_precision_m: 0.9622 - val_recall_m: 0.9622
# Epoch 287/300
# 45/45 - 9s - loss: 0.0406 - acc: 0.9852 - f1_m: 0.9852 - precision_m: 0.9852 - recall_m: 0.9852 - val_loss: 0.3768 - val_acc: 0.9311 - val_f1_m: 0.9351 - val_precision_m: 0.9351 - val_recall_m: 0.9351
# Epoch 288/300
# 45/45 - 9s - loss: 0.0368 - acc: 0.9866 - f1_m: 0.9866 - precision_m: 0.9866 - recall_m: 0.9866 - val_loss: 0.2471 - val_acc: 0.9267 - val_f1_m: 0.9308 - val_precision_m: 0.9308 - val_recall_m: 0.9308
# Epoch 289/300
# 45/45 - 8s - loss: 0.0387 - acc: 0.9861 - f1_m: 0.9861 - precision_m: 0.9861 - recall_m: 0.9861 - val_loss: 0.4752 - val_acc: 0.8840 - val_f1_m: 0.8904 - val_precision_m: 0.8904 - val_recall_m: 0.8904
# Epoch 290/300
# 45/45 - 8s - loss: 0.0411 - acc: 0.9851 - f1_m: 0.9851 - precision_m: 0.9851 - recall_m: 0.9851 - val_loss: 0.2648 - val_acc: 0.9608 - val_f1_m: 0.9632 - val_precision_m: 0.9632 - val_recall_m: 0.9632
# Epoch 291/300
# 45/45 - 9s - loss: 0.0381 - acc: 0.9861 - f1_m: 0.9861 - precision_m: 0.9861 - recall_m: 0.9861 - val_loss: 0.3350 - val_acc: 0.9546 - val_f1_m: 0.9574 - val_precision_m: 0.9574 - val_recall_m: 0.9574
# Epoch 292/300
# 45/45 - 8s - loss: 0.0444 - acc: 0.9839 - f1_m: 0.9839 - precision_m: 0.9839 - recall_m: 0.9839 - val_loss: 0.4027 - val_acc: 0.9062 - val_f1_m: 0.9107 - val_precision_m: 0.9107 - val_recall_m: 0.9107
# Epoch 293/300
# 45/45 - 8s - loss: 0.0387 - acc: 0.9860 - f1_m: 0.9860 - precision_m: 0.9860 - recall_m: 0.9860 - val_loss: 0.2586 - val_acc: 0.9592 - val_f1_m: 0.9617 - val_precision_m: 0.9617 - val_recall_m: 0.9617
# Epoch 294/300
# 45/45 - 8s - loss: 0.0381 - acc: 0.9861 - f1_m: 0.9861 - precision_m: 0.9861 - recall_m: 0.9861 - val_loss: 0.3716 - val_acc: 0.9436 - val_f1_m: 0.9470 - val_precision_m: 0.9470 - val_recall_m: 0.9470
# Epoch 295/300
# 45/45 - 8s - loss: 0.0403 - acc: 0.9850 - f1_m: 0.9850 - precision_m: 0.9850 - recall_m: 0.9850 - val_loss: 0.6154 - val_acc: 0.8466 - val_f1_m: 0.8547 - val_precision_m: 0.8547 - val_recall_m: 0.8547
# Epoch 296/300
# 45/45 - 8s - loss: 0.0407 - acc: 0.9848 - f1_m: 0.9848 - precision_m: 0.9848 - recall_m: 0.9848 - val_loss: 0.3915 - val_acc: 0.9249 - val_f1_m: 0.9289 - val_precision_m: 0.9289 - val_recall_m: 0.9289
# Epoch 297/300
# 45/45 - 8s - loss: 0.0391 - acc: 0.9857 - f1_m: 0.9857 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.4471 - val_acc: 0.9316 - val_f1_m: 0.9358 - val_precision_m: 0.9358 - val_recall_m: 0.9358
# Epoch 298/300
# 45/45 - 8s - loss: 0.0354 - acc: 0.9874 - f1_m: 0.9874 - precision_m: 0.9874 - recall_m: 0.9874 - val_loss: 0.2137 - val_acc: 0.9559 - val_f1_m: 0.9586 - val_precision_m: 0.9586 - val_recall_m: 0.9586
# Epoch 299/300
# 45/45 - 8s - loss: 0.0364 - acc: 0.9867 - f1_m: 0.9867 - precision_m: 0.9867 - recall_m: 0.9867 - val_loss: 0.3232 - val_acc: 0.9256 - val_f1_m: 0.9297 - val_precision_m: 0.9297 - val_recall_m: 0.9297
# Epoch 300/300
# 45/45 - 8s - loss: 0.0383 - acc: 0.9860 - f1_m: 0.9860 - precision_m: 0.9860 - recall_m: 0.9860 - val_loss: 0.4178 - val_acc: 0.9403 - val_f1_m: 0.9440 - val_precision_m: 0.9440 - val_recall_m: 0.9440

# %% [markdown]
# # Visualize the Training Output and Save the model

# %% [markdown]
# Visualize Learning Curve

# %%
# plot learning curve
plt.figure(figsize=(7,7))
plt.plot(history.history["loss"],label='Training Loss')
plt.title("Training and validation loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.plot(history.history["val_loss"],label='Validation Loss')
plt.legend()
plt.show()

# %%
# plot learning curve
plt.figure(figsize=(7,7))
plt.plot(1-np.array(history.history["acc"]),label='Training Error')
plt.title("Training and validation Error")
plt.ylabel("Error")
plt.xlabel("Epoch")
plt.plot(1-np.array(history.history["val_acc"]),label='Validation Error')
plt.legend()
plt.show()

# %% [markdown]
# Save output

# %%
# save the trained network
import imp, h5py
imp.reload(h5py)
model_fname = "/content/drive/My Drive/AIA_colab/Forest_fire/Classified Tiles/FCN-DK3_BAM_0.001_300_BR.hdf5"
fcn.save(model_fname)

# %% [markdown]
# # Test the Accuracy of the Model

# %%
Xtest = image_list["00001"]
Ytest = label_list["00001"]
cut = 128
overlap = 96

# %%
def evaluate_predictions(Xtest,cut, overlap, Ytest):
    """
    Function to predict full tiles strip-wise (as loading whole tiles might not fit in the memory).
    """
    Ytest = Ytest.copy()
    Ytest[Ytest!=2] = 0
    Ytest[Ytest==2] = 1
    ncols, nrows, nbands = Xtest.shape
    Xtest = np.expand_dims(Xtest, axis=0)
    total_map = np.zeros((nrows, ncols), dtype=np.uint8)
    first = True
    last = False
    if nrows%cut==0:
        numstrips = int(nrows/cut)
    else:
        numstrips = int(nrows/cut) + 1
    for i in range(numstrips):
        print("Strip number: %d" % i)
        if first:
            striptop = 0
            stripbottom = overlap
            height = cut
            X_sub = Xtest[:, cut*i-striptop:(cut*i)+height+stripbottom, :, :]
            first = False
        elif (not first) and (cut*(i+1)+1+overlap < nrows):
            striptop = overlap
            stripbottom = overlap
            height = cut
            X_sub = Xtest[:, cut*i-striptop:(cut*i)+height+stripbottom, :, :]
        else:
            print("Last hit!")
            striptop = overlap
            stripbottom = 0
            height = nrows - cut*i
            if (striptop+height)%(4)!=0:
                height = height*4
            X_sub = Xtest[:, -(striptop+height):, :, :]
            last = True        
        sub_nrows = X_sub.shape[1]
        sub_ncols = X_sub.shape[2]
        model = fcn
        
        sub_ns, sub_nb, _, __ = X_sub.shape
        cmap = model.predict_on_batch([X_sub])
        cmap = np.argmax(cmap[0], axis=2)
        if not last:
            total_map[cut*i:cut*i+height, :] = cmap[striptop:striptop+height, 0:total_map.shape[1]]
        else:
            total_map[-(height):, :] = cmap[-(height):, 0:total_map.shape[1]]
    return total_map
predictions_FCN = evaluate_predictions(Xtest, cut, overlap, Ytest)
# Out:
# Strip number: 0
# Strip number: 1
# Strip number: 2
# Strip number: 3
# Strip number: 4
# Strip number: 5
# Strip number: 6
# Strip number: 7
# Strip number: 8
# Strip number: 9
# Strip number: 10
# Strip number: 11
# Strip number: 12
# Strip number: 13
# Strip number: 14
# Last hit!
# Strip number: 15
# Last hit!

# %%
import string
from matplotlib import colors
from sklearn.metrics import f1_score, precision_score, recall_score

# set color codes of the classes
_others = [221, 61, 14]
_slums = [200, 199, 219]
ccolors = (_slums, _others)
NROWS, NCOLS, NBANDS = Xtest.shape


def print_map(predictions, idxarray, filename=None, title=None, ccolors=None):
    """Print the classified map.

    Keyword arguments:
    predictions -- the array output labels from the classification
    results
    idxarray -- the array of indices of the classified samples
    to be plotted.
    filename -- the name (with the directory) of the file where to
    write the map.
    ccolors -- an array of tuples containing rgb values for the classes
    Both arrays should match and be arranged accordingly. And the
    index of the color should match the value of the of prediction.
    """
    if predictions.size != idxarray.shape[0]:
        raise ValueError("There should be the same number of " +
                         "predictions and indices.")
    nrows, ncols = np.max(idxarray[:, 0])+1, np.max(idxarray[:, 1])+1
    classifiedmap = np.zeros((nrows, ncols, 3), dtype="uint8")
    idx = 0
    for prediction in predictions:
        classifiedmap[idxarray[idx, 0],
                      idxarray[idx, 1]] = np.asarray(ccolors[prediction])
        idx += 1
    if filename is None:
        fig = plt.figure()
        plt.imshow(classifiedmap)
        if title:
            plt.suptitle(title)
        plt.show()
    else:
        output_raster = gdal.GetDriverByName('GTiff').Create(filename,
                                                             NCOLS,
                                                             NROWS,
                                                             NUMBER_CLASSES,
                                                             gdal.GDT_Byte)
        for i in range(NUMBER_CLASSES):
            output_raster.GetRasterBand(i+1).WriteArray(classifiedmap.astype(np.uint8)[:, :, i])


def get_confusion_matrix(predictions, labels):
    """Compute the confusion matrix.

    Keyword arguments:
    prediction -- the array output labels from the classification
    results
    labels -- the  array of "true" labels from the test set
    Both arrays should match, be arranged accordingly, and
    have non-negative values.
    """
    classes = np.unique(labels)
    nbclasses = classes.size
    if labels.size != predictions.size:
        raise ValueError("There should be the same number of " +
                         "predictions and labels.")
    merged = np.concatenate((predictions.reshape(predictions.size, 1),
                             labels.reshape(labels.size, 1)), axis=1)
    CM = np.zeros((classes[-1] + 1, classes[-1] + 1))
    for c1 in classes:
        for c2 in classes:
            CM[c1, c2] = np.sum(np.logical_and(merged[:, 1] == c1,
                                               merged[:, 0] == c2))
    return CM


def cartesian(arrays, out=None):
    """Utility function to create cartesian image coordinates."""
    arrays = [np.asarray(x) for x in arrays]
    dtype = arrays[0].dtype
    n = np.prod([x.size for x in arrays])
    if out is None:
        out = np.zeros([n, len(arrays)], dtype=dtype)
    m = int(n / arrays[0].size)
    out[:, 0] = np.repeat(arrays[0], m)
    if arrays[1:]:
        cartesian(arrays[1:], out=out[0:m, 1:])
        for j in range(1, arrays[0].size):
            out[j*m:(j+1)*m, 1:] = out[0:m, 1:]
    return out

# %%
#plot Refrence Map
f, axarr = plt.subplots(1,3)
predictions = predictions_FCN
norm_ccolors = np.array(ccolors)/255.0


fig = axarr[0]
cmap = colors.ListedColormap(norm_ccolors)
bounds=[0,1,2]
norm = colors.BoundaryNorm(bounds, cmap.N)
labels = Ytest[:, :, 0].copy()
labels[labels!=2] = 0
labels[labels==2] = 1
fig.imshow(labels, cmap=cmap, norm=norm, interpolation="nearest", origin="upper")
fig.set_title("Reference map")

ax= axarr[1]
ax.imshow(predictions, cmap=cmap, norm=norm, interpolation="nearest", origin="upper")
ax.set_title("Results FCN")

rectangles = [matplotlib.patches.Rectangle((0, 0), 1, 1, color=norm_ccolors[r]) for r in range(norm_ccolors.shape[0])]
classes = [ "Non Burnt Area","Burnt Area"]
#Create legend from custom artist/label lists
fig.legend(rectangles, classes)
labels = labels.astype("uint8")

data=Xtest
data = data[:, :, 0:3]
_ = data[:, :, 0].copy()
data[:, :, 0] = data[:, :, 2]
data[:, :, 2] = _
data = data.astype(np.float)
for i in range(data.shape[2]):
    p2, p98 = np.percentile(data[:, :, i], (2, 98))
    data[:, :, i] = exposure.rescale_intensity(data[:, :, i],in_range=(p2, p98))

plt_sat=axarr[2]
a=plt_sat.set_title("Satellite image")
_=plt_sat.imshow(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-646dacdb5764> in <module>()
#      28 data = data[:, :, 0:3]
#      29 _ = data[:, :, 0].copy()
# ---> 30 data[:, :, 0] = data[:, :, 2]
#      31 data[:, :, 2] = _
#      32 data = data.astype(np.float)
#
# IndexError: index 2 is out of bounds for axis 2 with size 1

# %%
CM = get_confusion_matrix(predictions, labels)
OA = np.sum(np.diag(CM))/predictions.size
PA_bldg = ((predictions[labels==0]==labels[labels==0]).sum())/(labels[labels==0].size)
PA_rd = ((predictions[labels==1]==labels[labels==1]).sum())/(labels[labels==1].size)
print("Accuracy metrics of FCN results")
print("Overall Accuracy: %f" % OA)
#print("F1_score: %f" %(f1_score(labels, predictions, average="macro")))
print("PA of Burnt Area: %f" % PA_bldg)
print("PA of Not Burnt Area: %f" % PA_rd)
# Out:
# Accuracy metrics of FCN results
# Overall Accuracy: 0.934560
# PA of Burnt Area: 0.897593
# PA of Not Burnt Area: 0.975782
